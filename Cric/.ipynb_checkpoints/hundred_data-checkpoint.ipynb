# %%
import json
import pandas as pd
import numpy as np
import datetime

# %%
from os import listdir
from os.path import isfile, join
mypath='data'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
len(onlyfiles)
# Out:
# 187

# %%
f = open('data/1252666.json')
data = json.load(f)

# %%
list({'batter': 'T Kohler-Cadmore',
       'bowler': 'TK Curran',
       'extras': {'noballs': 2},
       'non_striker': 'SR Hain',
       'runs': {'batter': 1, 'extras': 2, 'total': 3}}['extras'].keys())[0]
# Out:
# 'noballs'

# %%
data
# Out:
# {'meta': {'data_version': '1.0.0', 'created': '2021-07-22', 'revision': 1},
#  'info': {'balls_per_over': 5,
#   'city': 'London',
#   'dates': ['2021-07-22'],
#   'event': {'name': "The Hundred Men's Competition", 'match_number': 1},
#   'gender': 'male',
#   'match_type': 'T20',
#   'officials': {'match_referees': ['DA Cosker'],
#    'reserve_umpires': ['RJ Warren'],
#    'tv_umpires': ['NJ Llong'],
#    'umpires': ['DJ Millns', 'MJ Saggers']},
#   'outcome': {'winner': 'Oval Invincibles', 'by': {'runs': 9}},
#   'overs': 20,
#   'player_of_match': ['SW Billings'],
#   'players': {'Oval Invincibles': ['JJ Roy',
#     'SM Curran',
#     'SP Narine',
#     'WG Jacks',
#     'SW Billings',
#     'CA Ingram',
#     'LJ Evans',
#     'TK Curran',
#     'NA Sowter',
#     'S Mahmood',
#     'RJW Topley'],
#    'Manchester Originals': ['PD Salt',
#     'JC Buttler',
#     'JM Clarke',
#     'C Munro',
#     'TA Lammonby',
#     'CR Brathwaite',
#     'CG Harrison',
#     'TW Hartley',
#     'FJ Klaassen',
#     'ST Finn',
#     'MW Parkinson']},
#   'registry': {'people': {'C Munro': 'af2c687b',
#     'CA Ingram': 'c995d726',
#     'CG Harrison': 'f655d740',
#     'CR Brathwaite': 'e342e5fb',
#     'DA Cosker': 'aac9f784',
#     'DJ Millns': '46ecfe40',
#     'FJ Klaassen': 'c042b412',
#     'JC Buttler': '99b75528',
#     'JJ Roy': 'd1c36f5c',
#     'JM Clarke': '2eca67f5',
#     'LJ Evans': '1c513d54',
#     'MJ Saggers': '402d5937',
#     'MW Parkinson': '19708692',
#     'NA Sowter': 'ee0c05c0',
#     'NJ Llong': '573fb985',
#     'PD Salt': '3d284ca3',
#     'RJ Warren': '9d1c62d7',
#     'RJW Topley': '8db7f47f',
#     'S Mahmood': '0f6db197',
#     'SM Curran': 'e94915e6',
#     'SP Narine': '9d430b40',
#     'ST Finn': 'ccdd8308',
#     'SW Billings': 'c16d4035',
#     'TA Lammonby': '73f1f6b0',
#     'TK Curran': 'e86754b2',
#     'TW Hartley': '22b98d7c',
#     'WG Jacks': '9caf69a1'}},
#   'season': '2021',
#   'team_type': 'club',
#   'teams': ['Oval Invincibles', 'Manchester Originals'],
#   'toss': {'decision': 'field', 'winner': 'Manchester Originals'},
#   'venue': 'Kennington Oval, London'},
#  'innings': [{'team': 'Oval Invincibles',
#    'overs': [{'over': 0,
#      'deliveries': [{'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'SM Curran',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'SM Curran',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SM Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SM Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'SM Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'SM Curran', 'kind': 'bowled'}]}]},
#     {'over': 1,
#      'deliveries': [{'batter': 'SP Narine',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SP Narine',
#        'bowler': 'TW Hartley',
#        'extras': {'legbyes': 1},
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'SP Narine',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'SP Narine',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SP Narine',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 2,
#      'deliveries': [{'batter': 'SP Narine',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JJ Roy',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'SP Narine',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JJ Roy',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'SP Narine',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SP Narine',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'SP Narine', 'kind': 'lbw'}]},
#       {'batter': 'WG Jacks',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 3,
#      'deliveries': [{'batter': 'JJ Roy',
#        'bowler': 'ST Finn',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JJ Roy',
#        'bowler': 'ST Finn',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JJ Roy',
#        'bowler': 'ST Finn',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'WG Jacks',
#        'bowler': 'ST Finn',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JJ Roy',
#        'bowler': 'ST Finn',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 4,
#      'deliveries': [{'batter': 'WG Jacks',
#        'bowler': 'TW Hartley',
#        'non_striker': 'JJ Roy',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JJ Roy',
#        'bowler': 'TW Hartley',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'JJ Roy',
#          'fielders': [{'name': 'TA Lammonby'}],
#          'kind': 'caught'}]},
#       {'batter': 'SW Billings',
#        'bowler': 'TW Hartley',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'WG Jacks',
#        'bowler': 'TW Hartley',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 5,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'WG Jacks',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'WG Jacks',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 6,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'WG Jacks',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'WG Jacks',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'WG Jacks',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'WG Jacks',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'WG Jacks',
#          'fielders': [{'name': 'ST Finn'}],
#          'kind': 'caught'}]},
#       {'batter': 'CA Ingram',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 7,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 8,
#      'deliveries': [{'batter': 'CA Ingram',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'ST Finn',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CA Ingram',
#        'bowler': 'ST Finn',
#        'extras': {'wides': 1},
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'ST Finn',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 9,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 10,
#      'deliveries': [{'batter': 'CA Ingram',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 11,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CA Ingram',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'SW Billings',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 12,
#      'deliveries': [{'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 13,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CA Ingram',
#        'bowler': 'CG Harrison',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'SW Billings',
#        'bowler': 'CG Harrison',
#        'non_striker': 'CA Ingram',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 14,
#      'deliveries': [{'batter': 'CA Ingram',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'CA Ingram',
#          'fielders': [{'name': 'CR Brathwaite'}],
#          'kind': 'caught'}]},
#       {'batter': 'LJ Evans',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'LJ Evans',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'LJ Evans',
#          'fielders': [{'name': 'PD Salt'}],
#          'kind': 'caught'}]},
#       {'batter': 'TK Curran',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TK Curran',
#        'bowler': 'ST Finn',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 15,
#      'deliveries': [{'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Billings',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 16,
#      'deliveries': [{'batter': 'TK Curran',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TK Curran',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Billings',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TK Curran',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TK Curran',
#        'bowler': 'CR Brathwaite',
#        'non_striker': 'SW Billings',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 17,
#      'deliveries': [{'batter': 'SW Billings',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'SW Billings',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'SW Billings',
#          'fielders': [{'name': 'JM Clarke'}],
#          'kind': 'caught'}]},
#       {'batter': 'NA Sowter',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'NA Sowter',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'NA Sowter', 'kind': 'bowled'}]},
#       {'batter': 'S Mahmood',
#        'bowler': 'FJ Klaassen',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 18,
#      'deliveries': [{'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TK Curran',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Mahmood',
#        'bowler': 'MW Parkinson',
#        'non_striker': 'TK Curran',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 19,
#      'deliveries': [{'batter': 'TK Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TK Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TK Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TK Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'TK Curran',
#        'bowler': 'TW Hartley',
#        'non_striker': 'S Mahmood',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]}],
#    'powerplays': [{'from': 0.1, 'to': 4.5, 'type': 'mandatory'}]},
#   {'team': 'Manchester Originals',
#    'overs': [{'over': 0,
#      'deliveries': [{'batter': 'PD Salt',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'PD Salt',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'PD Salt',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'PD Salt',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'PD Salt',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'PD Salt',
#          'fielders': [{'name': 'CA Ingram'}],
#          'kind': 'caught'}]}]},
#     {'over': 1,
#      'deliveries': [{'batter': 'JM Clarke',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JM Clarke',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SM Curran',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SM Curran',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JM Clarke',
#        'bowler': 'SM Curran',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 2,
#      'deliveries': [{'batter': 'JM Clarke',
#        'bowler': 'S Mahmood',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JM Clarke',
#        'bowler': 'S Mahmood',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'JM Clarke',
#        'bowler': 'S Mahmood',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JM Clarke',
#        'bowler': 'S Mahmood',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JM Clarke',
#        'bowler': 'S Mahmood',
#        'extras': {'legbyes': 1},
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}}]},
#     {'over': 3,
#      'deliveries': [{'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JM Clarke',
#        'bowler': 'SP Narine',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'JM Clarke',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 4,
#      'deliveries': [{'batter': 'JM Clarke',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'JM Clarke',
#          'fielders': [{'name': 'SW Billings'}],
#          'kind': 'caught'}]},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'review': {'by': 'Manchester Originals',
#         'umpire': 'DJ Millns',
#         'batter': 'C Munro',
#         'decision': 'upheld'},
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 5,
#      'deliveries': [{'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JC Buttler',
#        'bowler': 'RJW Topley',
#        'extras': {'legbyes': 1},
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'RJW Topley',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JC Buttler',
#        'bowler': 'RJW Topley',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 6,
#      'deliveries': [{'batter': 'C Munro',
#        'bowler': 'SP Narine',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'SP Narine',
#        'extras': {'wides': 1},
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'SP Narine',
#        'non_striker': 'JC Buttler',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'JC Buttler',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'JC Buttler',
#          'fielders': [{'name': 'CA Ingram'}],
#          'kind': 'caught'}]},
#       {'batter': 'TA Lammonby',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 7,
#      'deliveries': [{'batter': 'C Munro',
#        'bowler': 'WG Jacks',
#        'non_striker': 'TA Lammonby',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'WG Jacks',
#        'non_striker': 'TA Lammonby',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'WG Jacks',
#        'non_striker': 'TA Lammonby',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TA Lammonby',
#        'bowler': 'WG Jacks',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'WG Jacks',
#        'non_striker': 'TA Lammonby',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}}]},
#     {'over': 8,
#      'deliveries': [{'batter': 'TA Lammonby',
#        'bowler': 'NA Sowter',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'TA Lammonby',
#          'fielders': [{'name': 'CA Ingram'}],
#          'kind': 'caught'}]},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'extras': {'wides': 1},
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'extras': {'wides': 2},
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 2, 'total': 2}},
#       {'batter': 'C Munro',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 9,
#      'deliveries': [{'batter': 'C Munro',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 10,
#      'deliveries': [{'batter': 'C Munro',
#        'bowler': 'SP Narine',
#        'extras': {'legbyes': 1},
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'extras': {'wides': 1},
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'SP Narine',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 11,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'C Munro',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'C Munro',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'C Munro',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'C Munro',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'C Munro',
#          'fielders': [{'name': 'JJ Roy'}],
#          'kind': 'caught'}]}]},
#     {'over': 12,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 13,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'RJW Topley',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'RJW Topley',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CG Harrison',
#        'bowler': 'RJW Topley',
#        'extras': {'wides': 1},
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'RJW Topley',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'RJW Topley',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'RJW Topley',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 14,
#      'deliveries': [{'batter': 'CG Harrison',
#        'bowler': 'NA Sowter',
#        'extras': {'legbyes': 1},
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'NA Sowter',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 15,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SP Narine',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'SP Narine',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 16,
#      'deliveries': [{'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 17,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'SM Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'SM Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'SM Curran',
#        'non_striker': 'CG Harrison',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CG Harrison',
#        'bowler': 'SM Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CG Harrison',
#        'bowler': 'SM Curran',
#        'extras': {'legbyes': 1},
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}}]},
#     {'over': 18,
#      'deliveries': [{'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CG Harrison',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'CG Harrison',
#          'fielders': [{'name': 'SM Curran'}],
#          'kind': 'caught'}]},
#       {'batter': 'TW Hartley',
#        'bowler': 'TK Curran',
#        'non_striker': 'CR Brathwaite',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CR Brathwaite',
#        'bowler': 'TK Curran',
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 19,
#      'deliveries': [{'batter': 'CR Brathwaite',
#        'bowler': 'SM Curran',
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'player_out': 'CR Brathwaite',
#          'fielders': [{'name': 'JJ Roy'}],
#          'kind': 'caught'}]},
#       {'batter': 'FJ Klaassen',
#        'bowler': 'SM Curran',
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'FJ Klaassen',
#        'bowler': 'SM Curran',
#        'extras': {'noballs': 2},
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 0, 'extras': 2, 'total': 2}},
#       {'batter': 'FJ Klaassen',
#        'bowler': 'SM Curran',
#        'non_striker': 'TW Hartley',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TW Hartley',
#        'bowler': 'SM Curran',
#        'non_striker': 'FJ Klaassen',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TW Hartley',
#        'bowler': 'SM Curran',
#        'non_striker': 'FJ Klaassen',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]}],
#    'powerplays': [{'from': 0.1, 'to': 4.5, 'type': 'mandatory'}],
#    'target': {'overs': 20, 'runs': 146}}]}

# %%
team_info = pd.DataFrame({'team_name' : [], 'match_id' : [], 
                            'runs_scored' : [], 'wickets_lost' : [],
                            'runs_conceded' : [], 'wickets_taken' : [], 'date' : [], 'comp' : []})

player_info = pd.DataFrame({'player_name' : [], 'player_team' : [], 'match_id' : [],
                 'player_gender' : [], 'runs_scored' : [], 'runs_conceded' : [],
                 'wickets_taken' : [], 'out' : [], 'catches' : [], 'balls_faced' : [],
                 'fours' : [], 'sixes' : [], 'extras' : [], 'POM' : [], 'date' : []})
match_ids = []
h_teams = []
a_teams = []
cities = []
venues = []
dates = []
genders = []
toss_winners = []
toss_decisions = []
first_inn_runs = []
first_inn_wicks = []
second_inn_runs = []
second_inn_wicks = []
winners = []
outcomes = []
bat_firsts = []
fballs = []
sballs = []
bb_match = []
bb_innings = []
bb_ball = []
bb_bat = []
bb_bowl = []
bb_ns = []
bb_run = []
bb_ext = []
bb_ext_type = []
bb_tot = []
bb_wick = []
bb_how_out = []
bb_caught = []
bb_bowlt = []
bb_batt = []
sets = []


sub_catches = {}
match_number = 1


for d in onlyfiles:
    f = open('data/'+d)
    data = json.load(f)
    
    # collect game info
    
    city = data['info']['city']
    cities.append(city)
    venue = data['info']['venue']
    venues.append(venue)
    date = data['info']['dates'][0]
    dates.append(date)

    season = data['info']['season']
    
    gender = data['info']['gender']
    genders.append(gender)
    
    
    match_ids.append(match_number)
    
    h_team = data['info']['teams'][1]
    h_teams.append(h_team)
    a_team = data['info']['teams'][0]
    a_teams.append(a_team)
    
    
    
    toss_win = data['info']['toss']['winner']
    toss_winners.append(toss_win)
    toss_outcome = data['info']['toss']['decision']
    toss_decisions.append(toss_outcome)
    
    try:
        pom = data['info']['player_of_match'][0]
        winner = data['info']['outcome']['winner']
        winners.append(winner)
        if 'wickets' in data['info']['outcome']['by'].keys():
            outcome = str(data['info']['outcome']['by']['wickets']) + ' wickets'
        else:
            outcome = str(data['info']['outcome']['by']['runs']) + ' runs'
        outcomes.append(outcome)
    except:
        winners.append(np.nan)
        outcomes.append('no result')
        
    
    
    if toss_outcome ==  'bat':
        bat_first = toss_win
    else:
        if toss_win == h_team:
            bat_first = a_team
        else:
            bat_first = h_team
    bat_firsts.append(bat_first)
    
    h_players = data['info']['players'][h_team]

    h_game_runs_scored = {}
    h_game_runs_con = {}
    h_game_wick = {}
    h_game_out = {}
    h_catches = {}
    h_balls = {}
    h_fours = {}
    h_sixes = {}
    h_extras = {}
    h_balls_bowled = {}

    for p in h_players:
        h_game_runs_scored[p] = 0
        h_game_runs_con[p] = 0
        h_game_wick[p] = 0
        h_game_out[p] = 0
        h_catches[p] = 0
        h_balls[p] = 0
        h_fours[p] = 0
        h_sixes[p] = 0
        h_extras[p] = 0
        h_balls_bowled[p] = 0

    a_players = data['info']['players'][a_team]

    a_game_runs_scored = {}
    a_game_runs_con = {}
    a_game_wick = {}
    a_game_out = {}
    a_catches = {}
    a_balls = {}
    a_fours = {}
    a_sixes = {}
    a_extras = {}
    a_balls_bowled = {}

    for p in a_players:
        a_game_runs_scored[p] = 0
        a_game_runs_con[p] = 0
        a_game_wick[p] = 0
        a_game_out[p] = 0
        a_catches[p] = 0
        a_balls[p] = 0
        a_fours[p] = 0
        a_sixes[p] = 0
        a_extras[p] = 0
        a_balls_bowled[p] = 0

    

    runs_scored = {a_team : a_game_runs_scored, h_team : h_game_runs_scored} 
    runs_con = {a_team : a_game_runs_con, h_team : h_game_runs_con} 
    wickets = {a_team : a_game_wick, h_team : h_game_wick} 
    outs = {a_team : a_game_out, h_team : h_game_out} 
    catches = {a_team: a_catches, h_team : h_catches}
    balls = {a_team : a_balls, h_team : h_balls}
    fours = {a_team : a_fours, h_team : h_fours}
    sixes = {a_team : a_sixes, h_team : h_sixes}
    extras = {a_team : a_extras, h_team : h_extras}
    balls_bowled = {a_team : a_balls_bowled, h_team : h_balls_bowled}
    
    # first_innings_collection
    try:
        fteam = data['innings'][0]['team']

        if fteam == h_team:
            fbowl_team = a_team
        else:
            fbowl_team = h_team

        fg_runs_scored = 0
        finn_wicks = 0
        fball_bowled = 0


        for o in data['innings'][0]['overs']:

            set_runs = 0
            set_wick = 0
            set_number = 1
            for d in o['deliveries']:
                bat = d['batter']
                sets.append(set_number)
                set_number +=1
                bowl = d['bowler']
                ns = d['non_striker']
                bb_match.append(match_number)
                bb_innings.append(1)
                bb_ball.append(fball_bowled + 1)
                bb_bat.append(bat)
                bb_bowl.append(bowl)
                bb_ns.append(ns)
                bb_batt.append(fteam)
                bb_bowlt.append(fbowl_team)
                run = d['runs']['batter']
                bb_run.append(run)
                if run == 4:
                    fours[fteam][bat] += 1
                if run == 6:
                    sixes[fteam][bat] += 1
                runs_scored[fteam][bat] += run
                extra = d['runs']['extras']
                bb_ext.append(extra)
                bb_tot.append(run + extra)
                

                if 'extras' not in d.keys():
                    balls[fteam][bat] += 1
                    fball_bowled += 1
                    balls_bowled[fbowl_team][bowl] += 1
                    bb_ext_type.append(False)
                else:
                    bb_ext_type.append(list(d['extras'].keys())[0])
                    if 'byes' in d['extras'].keys() or 'legbyes' in d['extras'].keys() or 'noballs' in d['extras'].keys():
                        balls[fteam][bat] += 1
                        
                    if 'wides' in d['extras'].keys() or 'noballs' in d['extras'].keys():
                        extras[fbowl_team][bowl] += extra                   
                    if 'byes' in d['extras'].keys() or 'legbyes' in d['extras'].keys():
                        fball_bowled += 1
                        balls_bowled[fbowl_team][bowl] += 1
                        
                runs_con[fbowl_team][bowl] += run + extra

                set_runs += run
                set_runs += extra

                if 'wickets' in d.keys():
                    bb_wick.append(True)
                    bb_how_out.append(d['wickets'][0]['kind'])
                    wickets[fbowl_team][bowl] += 1
                    outs[fteam][d['wickets'][0]['player_out']] += 1
                    if d['wickets'][0]['kind'] == 'caught':
                        bb_caught.append(d['wickets'][0]['fielders'][0]['name'])
                        if 'substitute' not in d['wickets'][0]['fielders'][0].keys():
                            catches[fbowl_team][d['wickets'][0]['fielders'][0]['name']] +=1
                        else:
                            if d['wickets'][0]['fielders'][0]['name'] not in sub_catches.keys():
                                sub_catches[d['wickets'][0]['fielders'][0]['name']] = 1
                            else:
                                sub_catches[d['wickets'][0]['fielders'][0]['name']] += 1
                    elif d['wickets'][0]['kind'] == 'caught and bowled':
                        catches[fbowl_team][bowl] += 1
                        bb_caught.append(bowl)
                    else:
                        bb_caught.append(False)
                    set_wick += 1
                else:
                    bb_wick.append(False)
                    bb_how_out.append(False)
                    bb_caught.append(False)

                    
            fg_runs_scored += set_runs
            finn_wicks += set_wick

        first_inn_runs.append(fg_runs_scored)
        first_inn_wicks.append(finn_wicks)
        fballs.append(fball_bowled)
    except:
        fg_runs_scored = np.nan
        fball_bowled = np.nan
        finn_wickets = np.nan
        first_inn_runs.append(np.nan)
        first_inn_wicks.append(np.nan)
        fballs.append(fball_bowled)
    
    # second_inn_data_collection
    try:
        steam = data['innings'][1]['team']
    
        if steam == h_team:
            sbowl_team = a_team
        else:
            sbowl_team = h_team

        sg_runs_scored = 0
        sinn_wicks = 0
        sball_bowled = 0

        for o in data['innings'][1]['overs']:

            set_runs = 0
            set_wick = 0
            set_number = 1

            for d in o['deliveries']:
                bat = d['batter']
                sets.append(set_number)
                set_number +=1
                bowl = d['bowler']
                ns = d['non_striker']
                bb_match.append(match_number)
                bb_innings.append(2)
                bb_ball.append(sball_bowled + 1)
                bb_bat.append(bat)
                bb_bowl.append(bowl)
                bb_ns.append(ns)
                bb_batt.append(steam)
                bb_bowlt.append(sbowl_team)
                
                run = d['runs']['batter']
                bb_run.append(run)
                if run == 4:
                    fours[steam][bat] += 1
                if run == 6:
                    sixes[steam][bat] += 1
                runs_scored[steam][bat] += run
                extra = d['runs']['extras']
                bb_ext.append(extra)
                bb_tot.append(run + extra)

                if 'extras' not in d.keys():
                    balls[steam][bat] += 1
                    sball_bowled += 1
                    balls_bowled[sbowl_team][bowl] += 1
                    bb_ext_type.append(False)
                else:
                    bb_ext_type.append(list(d['extras'].keys())[0])
                    if 'byes' in d['extras'].keys() or 'legbyes' in d['extras'].keys() or 'noballs' in d['extras'].keys():
                        balls[steam][bat] += 1
                        
                    if 'wides' in d['extras'].keys() or 'noballs' in d['extras'].keys():
                        extras[sbowl_team][bowl] += extra
                    if 'byes' in d['extras'].keys() or 'legbyes' in d['extras'].keys():
                        sball_bowled += 1
                        balls_bowled[sbowl_team][bowl] += 1


                runs_con[sbowl_team][bowl] += run + extra

                set_runs += run
                set_runs += extra

                if 'wickets' in d.keys():
                    bb_wick.append(True)
                    bb_how_out.append(d['wickets'][0]['kind'])
                    wickets[sbowl_team][bowl] += 1
                    outs[steam][d['wickets'][0]['player_out']] += 1
                    if d['wickets'][0]['kind'] == 'caught':
                        bb_caught.append(d['wickets'][0]['fielders'][0]['name'])
                        if 'substitute' not in d['wickets'][0]['fielders'][0].keys():
                            catches[sbowl_team][d['wickets'][0]['fielders'][0]['name']] +=1
                        else:
                            if d['wickets'][0]['fielders'][0]['name'] not in sub_catches.keys():
                                sub_catches[d['wickets'][0]['fielders'][0]['name']] = 1
                            else:
                                sub_catches[d['wickets'][0]['fielders'][0]['name']] += 1
                    elif d['wickets'][0]['kind'] == 'caught and bowled':
                        bb_caught.append(bowl)
                        catches[sbowl_team][bowl] += 1
                    else:
                        bb_caught.append(False)
                    set_wick += 1
                else:
                    bb_wick.append(False)
                    bb_how_out.append(False)
                    bb_caught.append(False)

                    
            sg_runs_scored += set_runs
            sinn_wicks += set_wick
        second_inn_runs.append(sg_runs_scored)
        second_inn_wicks.append(sinn_wicks)
        sballs.append(sball_bowled)
    except:
        sg_runs_scored = np.nan
        sinn_wickets = np.nan
        sball_bowled = np.nan
        second_inn_runs.append(np.nan)
        second_inn_wicks.append(np.nan)
        sballs.append(sball_bowled)
        
    if h_team == fteam:
        rs = fg_runs_scored
        wl = finn_wicks
        rc = sg_runs_scored
        wt = sinn_wicks
        bb = fball_bowled
        bf = sball_bowled
        bat_first = True
        bat_second = False
        ht = True
        at = False
    else:
        rs = sg_runs_scored
        wl = sinn_wicks
        rc = fg_runs_scored
        wt = finn_wicks
        bb = sball_bowled
        bf = fball_bowled
        bat_first = False
        bat_second = True
        ht = False
        at = True
    
    team_df = pd.DataFrame({'team_name' : [h_team, a_team], 'match_id' : [match_number, match_number], 
                            'runs_scored' : [rs, rc], 'wickets_lost' : [wl, wt],
                            'runs_conceded' : [rc, rs], 'wickets_taken' : [wt, wl], 'date' : [date, date],
                            'comp' : [gender, gender], 'balls_bowled' : [bb, bf], 'balls_faced' : [bf, bb],
                            'bat_first' : [bat_first, bat_second], 'home' : [ht, at]})
    
    team_info = team_info.append(team_df, ignore_index = True)
    
    p_names = []
    p_teams = []
    p_match_ids = []
    p_gender = []
    p_runs_scored = []
    p_runs_conceded = []
    p_wickets = []
    p_outs = []
    p_catches = []
    p_balls = []
    p_fours = []
    p_sixes = []
    p_extras = []
    p_poms = []
    p_dates = []
    p_balls_bowled = []

    
    for t in runs_scored.keys():
        for p in runs_scored[t].keys():
            if p == pom:
                p_poms.append(True)
            else:
                p_poms.append(False)
            p_names.append(p)
            p_teams.append(t)
            p_gender.append(gender)
            p_match_ids.append(match_number)
            p_runs_scored.append(runs_scored[t][p])
            p_runs_conceded.append(runs_con[t][p])
            p_wickets.append(wickets[t][p])
            p_outs.append(outs[t][p])
            p_catches.append(catches[t][p])
            p_balls.append(balls[t][p])
            p_fours.append(fours[t][p])
            p_sixes.append(sixes[t][p])
            p_extras.append(extras[t][p])
            p_dates.append(date)
            p_balls_bowled.append(balls_bowled[t][p])
            
    player_df = pd.DataFrame({'player_name' : p_names, 'player_team' : p_teams, 'match_id' : p_match_ids,
                 'player_gender' : p_gender, 'runs_scored' : p_runs_scored, 'runs_conceded' : p_runs_conceded,
                 'wickets_taken' : p_wickets, 'out' : p_outs, 'catches' : p_catches, 'balls_faced' : p_balls,
                 'fours' : p_fours, 'sixes' : p_sixes, 'extras' : p_extras, 'POM' : p_poms, 'date' : p_dates,
                 'balls_bowled' : p_balls_bowled})
    player_info = player_info.append(player_df, ignore_index = True)
    match_number += 1
match_df =pd.DataFrame({'match_id' : match_ids, 'home_team' : h_teams, 'away_team' : a_teams,
                        'city' : cities, 'venue' : venues, 'date' : dates, 'competition' : genders,
                        'toss_winner' : toss_winners, 'toss_decision' : toss_decisions, 'bat_first' : bat_firsts, 
                        'first_innings_runs' : first_inn_runs, 'first_innings_wickets' : first_inn_wicks,
                        'second_innings_runs' : second_inn_runs, 'second_innings_wickets' : second_inn_wicks,
                        'winner' : winners, 'by' : outcomes, 'first_innings_balls' : fballs,
                        'second_innings_balls' : sballs})
# Out:
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# ...
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:410: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   team_info = team_info.append(team_df, ignore_index = True)
# C:\Users\alastair.tyson\AppData\Local\Temp\ipykernel_10844\4274201063.py:457: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info = player_info.append(player_df, ignore_index = True)

# %%
ball_by_ball = pd.DataFrame({'match_id' : bb_match, 'innings': bb_innings, 'ball_no' : bb_ball, 
                             'batting_team' : bb_batt, 'bowling team' : bb_bowlt,'batter' : bb_bat,       
                             'bowler' : bb_bowl,'non_batter' : bb_ns, 'runs' : bb_run, 'extras' : bb_ext,
                             'extra_type' : bb_ext_type, 'total_runs' : bb_tot, 
                             'wicket' : bb_wick, 'how_out' : bb_how_out, 'catcher' : bb_caught,'sets':sets})

# %%
wides = []
byes = []
catches = []
stumps = []
for i in range(len(ball_by_ball)):
    b = 0
    by = 0
    c = 0
    s = 0
    if ball_by_ball.loc[i,'extra_type'] in ['wides', 'noballs']:
        b += ball_by_ball.loc[i, 'extras']
        
    elif ball_by_ball.loc[i,'extra_type'] in ['byes']:
        by += ball_by_ball.loc[i, 'extras']
    if ball_by_ball.loc[i,'how_out'] in ['caught']:
        c += ball_by_ball.loc[i, 'wicket']
    elif ball_by_ball.loc[i,'how_out'] in ['stumped']:
        s += ball_by_ball.loc[i, 'wicket']
    wides.append(b)
    byes.append(by)
    catches.append(c)
    stumps.append(s)

# %%
ball_by_ball['penalty'] = wides
ball_by_ball['byes'] = byes
ball_by_ball['catches'] = catches
ball_by_ball['stumpings'] = stumps

# %%
pbat = ball_by_ball[ball_by_ball.match_id >=125].groupby(['match_id','batter']).agg({'ball_no':'count','runs':'sum','wicket':'sum',
                                                                             'catches':'sum'}).reset_index()

# %%
pbowl = ball_by_ball[ball_by_ball.match_id >=125].groupby(['match_id','bowler']).agg({'ball_no':'count','runs':'sum','wicket':'sum',
                                                                             'penalty':'sum'}).reset_index()

# %%
pbat.columns = ['match_id', 'player_name', 'balls_faced', 'runs_scored', 'out', 'catches']

# %%
pbowl.columns = ['match_id', 'player_name', 'balls_bowled', 'runs_conceded', 'how_many_out', 'extras']

# %%
match_info = match_df[['match_id', 'date', 'home_team', 'away_team', 'city', 'venue', 'competition',
                       'toss_winner', 'toss_decision', 'bat_first', 'winner', 'by']]

# %%
player_info['date'] = pd.to_datetime(player_info.date, format = '%Y-%m-%d')

names = []
curr_team = []
gender = []
games = []
runs_scored = []
not_outs = []
balls_faced = []
runs_conceded = []
wickets_taken = []
extras_conceded = []
catches = []
fours = []
sixes = []
times_batted = []
poms = []
balls_bowled = []
high_score = []
best_bowling = []


for p in player_info.player_name.unique():
    
    subset = player_info[player_info.player_name == p].reset_index(drop = True)
    
    names.append(p)
    curr_team.append(subset.loc[len(subset) - 1, 'player_team'])
    games.append(len(subset))
    runs_scored.append(int(subset.runs_scored.sum()))
    tb = len(subset[subset.balls_faced>0])

    no = int(len(subset[subset.balls_faced>0]) - subset.out.sum())
    if no < 1:
        no = np.nan
    not_outs.append(no)
    balls_faced.append(int(subset.balls_faced.sum()))
    wickets_taken.append(subset.wickets_taken.sum())
    fours.append(int(subset.fours.sum()))
    sixes.append(int(subset.sixes.sum()))
    hs = int(subset.runs_scored.max())
    if tb < 1:
        hs = np.nan
    high_score.append(hs)
    balls_bowled.append(int(subset.balls_bowled.sum()))
    runs_conceded.append(int(subset.runs_conceded.sum()))
    extras_conceded.append(int(subset.extras.sum()))
    cat = subset.catches.sum()
    gender.append(subset.loc[0, 'player_gender'])
    times_batted.append(tb)
    if p in sub_catches.keys():
        cat += sub_catches[p]
    catches.append(int(cat))   
    poms.append(int(subset.POM.sum()))
    max_wick = int(subset.sort_values(by = 'wickets_taken', ascending = False).wickets_taken.max())

    accomp_run = int(subset[subset.wickets_taken == max_wick].sort_values(by = 'runs_conceded').runs_conceded.min())
    b_bowl = str(accomp_run) +'-' + str(max_wick)
    if b_bowl == '0-0':
        b_bowl = np.nan
    best_bowling.append(b_bowl)
    
    
player_stats = pd.DataFrame({'player_name' : names, 'gender' : gender, 'current_team' : curr_team, 'games_played' : games,
                             'runs_scored' : runs_scored, 'innings' : times_batted, 
                             'not_outs' : not_outs, 'balls_faced' : balls_faced,
                             'fours' : fours, 'sixes' :sixes, 'high_score' : high_score,
                             'balls_bowled' : balls_bowled, 'runs_conceded' : runs_conceded, 
                             'best_bowling' : best_bowling,'wickets_taken':wickets_taken,
                             'extras' : extras_conceded, 'catches' : catches, 'POMs' :poms})

# %%
pbat.to_csv('2023_player_bat_stats.csv',index = False)
pbowl.to_csv('2023_player_bowl_stats.csv',index = False)
player_stats.to_csv('overall_player_stats_v4.csv', index = False)  #note, includes catches as substitute fielder
match_info.to_csv('match_information_v2.csv', index = False)
