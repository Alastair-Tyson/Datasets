# %%
import pandas as pd

# %%
df=pd.read_csv('tracking_activity.csv')

# %%
coords=[]
for i in range(len(df)):

    coords.append(str(df.iloc[i,0])+','+str(df.iloc[i,1]))

# %%
df['Coordinates']=coords

# %%
df.drop(['Latitude','Longitude'],axis=1,inplace=True)

# %%
df['Date']=pd.to_datetime(df.Date)

# %%
df=df[['Coordinates','Date','Place']]

# %%
df.to_csv('tracking_activity_gds.csv',index=False)

# %%
coord=df[df.Place=='Castle Douglas']['Coordinates'][66]

# %%
import random

# %%
import datetime

# %%
datetime.datetime(2012,12,25)
# Out:
# datetime.datetime(2012, 12, 25, 0, 0)

# %%
Date=[]
Place=[]
coordinates=[]
for year in [2012,2013,2014,2016,2018]:
    no=random.randint(1,20)
    for i in range(no):
        h=random.randint(8,20)
        mins=random.randint(0,59)
        Date.append(datetime.datetime(year,12,25,h,mins))
        Place.append('Castle Douglas')
        coordinates.append(coord)

# %%
df2=pd.DataFrame({'Date':Date,'Place':Place,'Coordinates':coordinates})

# %%
df2=df2[['Coordinates','Date','Place']]

# %%
df3=pd.concat([df,df2])

# %%
df3
# Out:
#                     Coordinates                Date           Place
# 0   51.6084,0.29725999999999997 2014-08-11 04:36:00          Warley
# 1   51.6084,0.29725999999999997 2014-09-11 12:59:00          Warley
# 2   51.6084,0.29725999999999997 2014-10-11 16:02:00          Warley
# 3   51.6084,0.29725999999999997 2014-10-11 16:18:00          Warley
# 4   51.6084,0.29725999999999997 2014-10-11 22:15:00          Warley
# ..                          ...                 ...             ...
# 32             54.9401,-3.93054 2018-12-25 14:57:00  Castle Douglas
# 33             54.9401,-3.93054 2018-12-25 10:44:00  Castle Douglas
# 34             54.9401,-3.93054 2018-12-25 19:59:00  Castle Douglas
# 35             54.9401,-3.93054 2018-12-25 13:10:00  Castle Douglas
# 36             54.9401,-3.93054 2018-12-25 10:41:00  Castle Douglas
#
# [10945 rows x 3 columns]

# %%
df3=df3.sort_values(by='Date').reset_index(drop=True)

# %%
df3.to_csv('tracking_activity_gds.csv',index=False)

# %%
df
# Out:
#        Latitude  Longitude              Date              Place
# 0      51.60840    0.29726  08/11/2014 04:36             Warley
# 1      51.60840    0.29726  09/11/2014 12:59             Warley
# 2      51.60840    0.29726  10/11/2014 16:02             Warley
# 3      51.60840    0.29726  10/11/2014 16:18             Warley
# 4      51.60840    0.29726  10/11/2014 22:15             Warley
# ...         ...        ...               ...                ...
# 10903  54.77530   -1.58000  26/09/2021 11:36             Durham
# 10904  54.85432   -1.57504  26/09/2021 11:46  Chester-le-Street
# 10905  54.85432   -1.57504  27/09/2021 18:19  Chester-le-Street
# 10906  54.85432   -1.57504  27/09/2021 18:37  Chester-le-Street
# 10907  54.85432   -1.57504  28/09/2021 07:37  Chester-le-Street
#
# [10908 rows x 4 columns]

# %%
datetime.datetime(2012,12,25,6,45,34).hour
# Out:
# 6

# %%
def time_maker(date,time='All Day'):
    if time=='All Day':
        hour=random.randint(9,21)
    elif time=='Morning':
        hour=random.randint(8,13)
    elif time=='Afternoon':
        hour=random.randint(12,19)
    elif time=='Day':
        hour=random.randint(9,17)
    elif time=='Rest':
        r=random.randint(0,1)
        if r==0:
            hour=random.randint(7,8)
        else:
            hour=random.randint(17,21)
    else:
        hour=random.randint(20,23)
    year=date.year
    month=date.month
    day=date.day
    minute=random.randint(0,59)
    second=random.randint(0,59)
    return datetime.datetime(year,month,day,hour,minute,second)

# %%
dat=[]
for i in range(len(df)):
    dat.append(df.iloc[i,2].date())

# %%
dates=[]
places=[]

for i in pd.date_range(start="2011-01-01",end="2016-12-31"):
    if i not in dat:
        if i.year==2011:
            if i in pd.date_range(start="2011-01-01",end="2011-01-05") or i in pd.date_range(start="2011-03-27",end="2011-04-15") or i in pd.date_range(start="2011-12-18",end="2011-12-28"):
                r=random.randint(1,5)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2011-01-06",end="2011-03-26") or i in pd.date_range(start="2011-04-16",end="2011-12-11"):
                r=random.randint(1,5)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('St Andrews')
            else:
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Doune')
        elif i.year==2012:
            if i in pd.date_range(start="2012-01-01",end="2012-01-03"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Doune')
            elif i in pd.date_range(start="2012-01-04",end="2012-03-26") or i in pd.date_range(start="2012-04-06",end="2012-06-30"):
                r=random.randint(1,5)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('St Andrews')
            elif i in pd.date_range(start="2012-03-27",end="2012-04-05"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Prestatyn')
            elif i in pd.date_range(start="2012-07-01",end="2012-07-25") or i in pd.date_range(start="2012-08-29",end="2012-09-03") or i in pd.date_range(start="2012-12-23",end="2012-12-31") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2012-07-26",end="2012-08-28") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Edinburgh')
            elif i in pd.date_range(start="2012-09-04",end="2012-09-10") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Harold Wood')
            elif i in pd.date_range(start="2012-09-11",end="2012-09-12") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Cheshunt')
            elif i in pd.date_range(start="2012-09-13",end="2012-12-22") :
                if i.weekday() in [1,2,3,4,6]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Harold Wood')
                elif i.weekday()==2:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Harold Wood')
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Cambridge')
                elif i.weekday==5:
                    roll=random.randint(0,10)
                    if roll<7:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Harold Wood')
                    if roll<9:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Harold Wood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Romford')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Harold Wood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
        elif i.year==2013:
            if i in pd.date_range(start="2013-01-01",end="2012-04-01") or i in pd.date_range(start="2013-04-08",end="2013-07-23"):
                if i.weekday() in [1,2,3,4,6]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Harold Wood')
                elif i.weekday()==2:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Harold Wood')
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Cambridge')
                elif i.weekday==5:
                    roll=random.randint(0,10)
                    if roll<7:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Harold Wood')
                    if roll<9:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Harold Wood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Romford')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Harold Wood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
            elif i in pd.date_range(start="2013-04-02",end="2013-04-07"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Prestatyn')
            elif i in pd.date_range(start="2013-07-24",end="2013-08-02"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('West Buckland')
            elif i in pd.date_range(start="2013-08-03",end="2013-08-16"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Harold Wood')
            elif i in pd.date_range(start="2013-08-16",end="2013-08-23"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2013-08-24",end="2013-09-02"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')
            elif i in pd.date_range(start="2013-09-03",end="2013-09-05") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Cheshunt')
            elif i in pd.date_range(start="2013-09-06",end="2013-12-22") :
                if i.weekday() in [0,1,2,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday() ==3 :
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Morning'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Afternoon'))
                        places.append('Chelmsford')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    roll=random.randint(0,10)
                    if roll<6:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harold Wood')
                    if roll<9:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Romford')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
        elif i.year==2014:
            if i in pd.date_range(start="2014-01-01",end="2014-01-02")  or i in pd.date_range(start="2014-12-23",end="2014-12-31"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2014-01-03",end="2014-04-01") or i in pd.date_range(start="2014-04-15",end="2014-07-24"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    roll=random.randint(0,10)
                    if roll<6:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harold Wood')
                    if roll<9:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Romford')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
            elif i in pd.date_range(start="2014-04-09",end="2014-04-14"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Prestatyn')
            elif i in pd.date_range(start="2014-04-02",end="2014-04-08") or i in pd.date_range(start="2014-04-09",end="2014-04-14"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')
            elif i in pd.date_range(start="2014-07-25",end="2014-08-01") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Blandford Forum')
            elif i in pd.date_range(start="2014-08-02",end="2014-08-15") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Whitby')
            elif i in pd.date_range(start="2014-08-16",end="2014-08-25") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Sparkford')
            elif i in pd.date_range(start="2014-08-26",end="2014-08-31") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')
            elif i in pd.date_range(start="2014-09-01",end="2014-09-02") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Cheshunt')
            elif i in pd.date_range(start="2014-09-03",end="2014-09-19") :
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    roll=random.randint(0,10)
                    if roll<6:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harold Wood')
                    if roll<9:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Romford')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
            elif i in pd.date_range(start="2014-09-20",end="2014-09-20"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i,'Morning'))
                    places.append('Brentwood')
                r=random.randint(4,7)
                for j in range(r):
                    dates.append(time_maker(i,'Afternoon'))
                    places.append('City of Westminster')
            elif i in pd.date_range(start="2014-09-21",end="2014-12-22") :
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
                    if roll<5:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
        elif i.year==2015:
            if i in pd.date_range(start="2015-01-01",end="2015-01-02")  or i in pd.date_range(start="2015-05-23",end="2015-05-23") or i in pd.date_range(start="2015-12-26",end="2015-12-31"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2014-09-20",end="2014-09-20"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i,'Morning'))
                    places.append('Brentwood')
                r=random.randint(4,7)
                for j in range(r):
                    dates.append(time_maker(i,'Afternoon'))
                    places.append('City of Westminster')
            elif i in pd.date_range(start="2015-01-03",end="2015-03-27") or i in pd.date_range(start="2015-04-15",end="2015-05-22") or i in pd.date_range(start="2015-06-01",end="2015-07-22"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Brentwood')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
                    if roll<5:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Brentwood')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Brentwood')
            elif i in pd.date_range(start="2015-03-28",end="2015-04-02"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Prestatyn')
            elif i in pd.date_range(start="2015-04-03",end="2015-04-13"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Harpenden')
            elif i in pd.date_range(start="2015-04-14",end="2015-04-15"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')
            elif i in pd.date_range(start="2015-05-24",end="2015-05-27"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Edinburgh')
            elif i in pd.date_range(start="2015-05-28",end="2015-05-31"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')
            elif i in pd.date_range(start="2015-07-24",end="2015-07-31"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Blandford Forum')
            elif i in pd.date_range(start="2015-08-01",end="2015-08-04"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Brentwood')

            elif i in pd.date_range(start="2015-08-05",end="2015-08-05"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('City of Westminster')
            elif i in pd.date_range(start="2015-08-06",end="2015-08-31"):
                roll=random.randint(1,6)
                if roll<5:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Brentwood')
                else:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Harpenden')
            elif i in pd.date_range(start="2015-09-01",end="2015-09-02"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Cheshunt')
            elif i in pd.date_range(start="2015-09-03",end="2015-12-22"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Warley')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Warley')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Warley')
                    if roll<5:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Warley')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Warley')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Warley')
            elif i in pd.date_range(start="2015-12-23",end="2015-12-25"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Cobham')

        elif i.year==2016:
            if i in pd.date_range(start="2016-01-01",end="2016-01-02") or i in pd.date_range(start="2016-12-23",end="2016-12-31"):
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Castle Douglas')
            elif i in pd.date_range(start="2016-01-03",end="2016-04-13"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Warley')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Warley')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Warley')
                    if roll<5:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Warley')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<8:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Warley')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Warley')
            elif i in pd.date_range(start="2016-04-14",end="2016-07-23"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Hutton')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Hutton')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Hutton')
                    if roll<3:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Hutton')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<4:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Hutton')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Hutton')
            elif i in pd.date_range(start="2016-07-24",end="2016-08-02") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Blandford Forum')
            elif i in pd.date_range(start="2016-08-03",end="2016-08-05") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Harpenden')
            elif i in pd.date_range(start="2016-08-06",end="2016-08-06") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i,'Morning'))
                    places.append('Harpenden')
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i,'Afternoon'))
                    places.append('Hatfield')
            elif i in pd.date_range(start="2016-08-07",end="2016-08-08") or i in pd.date_range(start="2016-08-10",end="2016-08-10") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Carlisle')
            elif i in pd.date_range(start="2016-08-09",end="2016-08-09") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Durham')
            elif i in pd.date_range(start="2016-08-11",end="2016-08-31") :
                r=random.randint(1,3)
                for j in range(r):
                    dates.append(time_maker(i))
                    places.append('Hutton')
            elif i in pd.date_range(start="2016-09-01",end="2016-12-22"):
                if i.weekday() in [0,1,2,3,4]:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Rest'))
                        places.append('Hutton')
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i,'Day'))
                        places.append('Billericay')
                elif i.weekday()==6:
                    r=random.randint(1,3)
                    for j in range(r):
                        dates.append(time_maker(i))
                        places.append('Hutton')
                else:
                    roll=random.randint(0,10)
                    if roll<2:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Hutton')
                    if roll<3:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Hutton')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('City of Westminster')
                    if roll<4:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Morning'))
                            places.append('Hutton')
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i,'Afternoon'))
                            places.append('Harpenden')
                    else:
                        r=random.randint(1,3)
                        for j in range(r):
                            dates.append(time_maker(i))
                            places.append('Hutton')

# %%
dic={}
for i in range(len(df)):
    lat=df.iloc[i,0]
    long=df.iloc[i,1]
    plac=df.iloc[i,3]
    dic[plac]=[lat,long]

# %%
dic['Sparkford']=[51.03377859564301, -2.5695690328935092]

# %%
lats=[]
longs=[]

for i in range(len(df2)):
    lats.append(dic[df2.iloc[i,1]][0])
    longs.append(dic[df2.iloc[i,1]][1])

# %%
df2=pd.DataFrame({'Date':dates,'Place':places})

# %%
df2['Latitude']=lats
df2['Longitude']=longs

# %%
df2=df2[['Latitude','Longitude','Date','Place']]

# %%
df.groupby([df['Date'].dt.year]).count()
# Out:
#       Latitude  Longitude  Date  Place
# Date
# 2014        70         70    70     70
# 2015       353        353   353    353
# 2016        65         65    65     65
# 2017      1163       1163  1163   1163
# 2018      1135       1135  1135   1135
# 2019      3377       3377  3377   3377
# 2020      2602       2602  2602   2602
# 2021      2143       2143  2143   2143

# %%
df3=pd.concat([df,df2])

# %%
df3.groupby([df3['Date'].dt.year]).count()
# Out:
#       Latitude  Longitude  Date  Place
# Date
# 2011      1118       1118  1118   1118
# 2012       846        846   846    846
# 2013       726        726   726    726
# 2014      1274       1274  1274   1274
# 2015       909        909   909    909
# 2016      1295       1295  1295   1295
# 2017      1163       1163  1163   1163
# 2018      1135       1135  1135   1135
# 2019      3377       3377  3377   3377
# 2020      2602       2602  2602   2602
# 2021      2143       2143  2143   2143

# %%
df3.sort_values(by='Date')
# Out:
#        Latitude  Longitude                Date              Place
# 0      54.94010   -3.93054 2011-01-01 15:09:39     Castle Douglas
# 1      54.94010   -3.93054 2011-01-01 15:44:25     Castle Douglas
# 2      54.94010   -3.93054 2011-01-01 17:02:54     Castle Douglas
# 4      54.94010   -3.93054 2011-01-02 14:35:42     Castle Douglas
# 3      54.94010   -3.93054 2011-01-02 15:29:17     Castle Douglas
# ...         ...        ...                 ...                ...
# 10830  54.77530   -1.58000 2021-12-09 09:49:00             Durham
# 10831  54.76056   -1.55033 2021-12-09 12:34:00         Shincliffe
# 10832  54.77530   -1.58000 2021-12-09 14:55:00             Durham
# 10834  54.85432   -1.57504 2021-12-09 15:13:00  Chester-le-Street
# 10833  54.85432   -1.57504 2021-12-09 15:13:00  Chester-le-Street
#
# [16588 rows x 4 columns]

# %%
# importing the module
import json
 
# Opening JSON file
with open('2021_DECEMBER.json') as json_file:
    dec = json.load(json_file)
with open('2021_November.json') as json_file:
    nov = json.load(json_file)
with open('2021_October.json') as json_file:
    octo = json.load(json_file)
with open('2021_September.json') as json_file:
    sep = json.load(json_file)
with open('location_history.json') as json_file:
    fb = json.load(json_file)

# %%
lats=[]
longs=[]
stamps=[]
for i in dec['timelineObjects']:
    if 'activitySegment' in i:
        lats.append(i['activitySegment']['startLocation']['latitudeE7'])
        longs.append(i['activitySegment']['startLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['startTimestampMs'])
        lats.append(i['activitySegment']['endLocation']['latitudeE7'])
        longs.append(i['activitySegment']['endLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['endTimestampMs'])
    elif 'placeVisit' in i:
        lats.append(i['placeVisit']['location']['latitudeE7'])
        longs.append(i['placeVisit']['location']['longitudeE7'])
        stamps.append(i['placeVisit']['duration']['startTimestampMs'])

# %%
for i in nov['timelineObjects']:
    if 'activitySegment' in i:
        lats.append(i['activitySegment']['startLocation']['latitudeE7'])
        longs.append(i['activitySegment']['startLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['startTimestampMs'])
        lats.append(i['activitySegment']['endLocation']['latitudeE7'])
        longs.append(i['activitySegment']['endLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['endTimestampMs'])
    elif 'placeVisit' in i:
        lats.append(i['placeVisit']['location']['latitudeE7'])
        longs.append(i['placeVisit']['location']['longitudeE7'])
        stamps.append(i['placeVisit']['duration']['startTimestampMs'])

# %%
for i in octo['timelineObjects']:
    if 'activitySegment' in i:
        lats.append(i['activitySegment']['startLocation']['latitudeE7'])
        longs.append(i['activitySegment']['startLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['startTimestampMs'])
        lats.append(i['activitySegment']['endLocation']['latitudeE7'])
        longs.append(i['activitySegment']['endLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['endTimestampMs'])
    elif 'placeVisit' in i:
        lats.append(i['placeVisit']['location']['latitudeE7'])
        longs.append(i['placeVisit']['location']['longitudeE7'])
        stamps.append(i['placeVisit']['duration']['startTimestampMs'])

# %%
for i in sep['timelineObjects']:
    if 'activitySegment' in i:
        lats.append(i['activitySegment']['startLocation']['latitudeE7'])
        longs.append(i['activitySegment']['startLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['startTimestampMs'])
        lats.append(i['activitySegment']['endLocation']['latitudeE7'])
        longs.append(i['activitySegment']['endLocation']['longitudeE7'])
        stamps.append(i['activitySegment']['duration']['endTimestampMs'])
    elif 'placeVisit' in i:
        lats.append(i['placeVisit']['location']['latitudeE7'])
        longs.append(i['placeVisit']['location']['longitudeE7'])
        stamps.append(i['placeVisit']['duration']['startTimestampMs'])

# %%
dec
# Out:
# {'timelineObjects': [{'activitySegment': {'startLocation': {'latitudeE7': 548495875,
#      'longitudeE7': -15644669,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548500885,
#      'longitudeE7': -15624190,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638344797171',
#      'endTimestampMs': '1638345039340'},
#     'distance': 217,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 96.8065857887268},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 1.5603693202137947},
#      {'activityType': 'STILL', 'probability': 1.1614466086030006},
#      {'activityType': 'RUNNING', 'probability': 0.20554084330797195},
#      {'activityType': 'CYCLING', 'probability': 0.14148587360978127},
#      {'activityType': 'IN_BUS', 'probability': 0.09766451548784971},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.010375249985372648},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.004738681309390813},
#      {'activityType': 'IN_TRAM', 'probability': 0.0037439895095303655},
#      {'activityType': 'FLYING', 'probability': 0.0030257011530920863},
#      {'activityType': 'IN_TRAIN', 'probability': 0.0024984314222820103},
#      {'activityType': 'IN_FERRY', 'probability': 0.0016867501472006552},
#      {'activityType': 'SKIING', 'probability': 0.0005984848485240946},
#      {'activityType': 'SAILING', 'probability': 0.00024643454707984347},
#      {'activityType': 'IN_VEHICLE', 'probability': 8.088768370384525e-10}],
#     'waypointPath': {'waypoints': [{'latE7': 548496437, 'lngE7': -15644849},
#       {'latE7': 548497200, 'lngE7': -15634688},
#       {'latE7': 548498954, 'lngE7': -15627461}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495508,
#      'longitudeE7': -15607875,
#      'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#      'address': 'Chester-le-Street\nDH3 3SH\nUK',
#      'name': 'The Riverside',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 55.170296},
#     'duration': {'startTimestampMs': '1638345039340',
#      'endTimestampMs': '1638348293236'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'childVisits': [{'location': {'latitudeE7': 548499740,
#        'longitudeE7': -15624610,
#        'placeId': 'ChIJ0TVEBWN8fkgRFOLD0oKd_LI',
#        'address': 'County grounds\nRiverside\nBradman Dr\nChester-le-Street\nDH3 3SH\nUK',
#        'name': 'Bannatyne Health Club',
#        'sourceInfo': {'deviceTag': -1155862105},
#        'locationConfidence': 85.10577},
#       'duration': {'startTimestampMs': '1638345039340',
#        'endTimestampMs': '1638348293236'},
#       'placeConfidence': 'MEDIUM_CONFIDENCE',
#       'centerLatE7': 548500963,
#       'centerLngE7': -15624074,
#       'visitConfidence': 89,
#       'otherCandidateLocations': [{'latitudeE7': 548537302,
#         'longitudeE7': -15620971,
#         'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#         'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#         'name': 'Riverside Park',
#         'locationConfidence': 0.29174963},
#        {'latitudeE7': 548487020,
#         'longitudeE7': -15604070,
#         'placeId': 'ChIJxU9Gv2J8fkgREE_zNjv5p7g',
#         'locationConfidence': 0.2464965},
#        {'latitudeE7': 548488557,
#         'longitudeE7': -15623395,
#         'placeId': 'ChIJo8fPrmN8fkgRnZ7w6GU93M4',
#         'locationConfidence': 0.052081693},
#        {'latitudeE7': 548508015,
#         'longitudeE7': -15628304,
#         'placeId': 'ChIJF2yiPWN8fkgR2waKUsXJZzc',
#         'locationConfidence': 0.05130969}],
#       'editConfirmationStatus': 'NOT_CONFIRMED'}],
#     'centerLatE7': 548500963,
#     'centerLngE7': -15624074,
#     'visitConfidence': 89,
#     'otherCandidateLocations': [{'latitudeE7': 548495636,
#       'longitudeE7': -15644417,
#       'placeId': 'ChIJv6-je2N8fkgR7qF4kN85X8M',
#       'semanticType': 'TYPE_HOME',
#       'locationConfidence': 14.1536455},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.76782095},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.41349134},
#      {'latitudeE7': 548513100,
#       'longitudeE7': -15623900,
#       'placeId': 'ChIJOVqgJWN8fkgRKUm8IVBlrHM',
#       'locationConfidence': 0.3869864}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548498147,
#      'longitudeE7': -15628104,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548496823,
#      'longitudeE7': -15647885,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638348293236',
#      'endTimestampMs': '1638348423462'},
#     'distance': 127,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 97.17697501182556},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 1.674637757241726},
#      {'activityType': 'STILL', 'probability': 0.4895716905593872},
#      {'activityType': 'CYCLING', 'probability': 0.3148313146084547},
#      {'activityType': 'RUNNING', 'probability': 0.18058675341308117},
#      {'activityType': 'IN_BUS', 'probability': 0.09444578900001943},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.03676076594274491},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.009233087621396407},
#      {'activityType': 'IN_TRAIN', 'probability': 0.006664393731625751},
#      {'activityType': 'IN_TRAM', 'probability': 0.0045122840674594045},
#      {'activityType': 'IN_FERRY', 'probability': 0.004375207936391234},
#      {'activityType': 'SKIING', 'probability': 0.003437940904404968},
#      {'activityType': 'FLYING', 'probability': 0.0032973181077977642},
#      {'activityType': 'SAILING', 'probability': 0.0006666755325568374},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.3875348786607233e-09}],
#     'waypointPath': {'waypoints': [{'latE7': 548498115, 'lngE7': -15627760},
#       {'latE7': 548497200, 'lngE7': -15634688},
#       {'latE7': 548496131, 'lngE7': -15648019}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.311356},
#     'duration': {'startTimestampMs': '1638348423462',
#      'endTimestampMs': '1638386647223'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548495826,
#     'centerLngE7': -15644576,
#     'visitConfidence': 90,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.754636},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.63224006},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.15778309},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.08891894}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548492635,
#      'longitudeE7': -15638869,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 547789690,
#      'longitudeE7': -15726525,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638386647223',
#      'endTimestampMs': '1638387773077'},
#     'distance': 7845,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 92.89643168449402},
#      {'activityType': 'WALKING', 'probability': 5.910832062363625},
#      {'activityType': 'CYCLING', 'probability': 0.2752065658569336},
#      {'activityType': 'IN_BUS', 'probability': 0.269569456577301},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.2668974921107292},
#      {'activityType': 'STILL', 'probability': 0.21892853546887636},
#      {'activityType': 'RUNNING', 'probability': 0.08155927062034607},
#      {'activityType': 'IN_FERRY', 'probability': 0.022583245299756527},
#      {'activityType': 'FLYING', 'probability': 0.019261018314864486},
#      {'activityType': 'IN_TRAIN', 'probability': 0.01456550817238167},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.01026765166898258},
#      {'activityType': 'IN_TRAM', 'probability': 0.006337421655189246},
#      {'activityType': 'SKIING', 'probability': 0.0049780606786953285},
#      {'activityType': 'SAILING', 'probability': 0.0025825871489359997},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.5310470946605648e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 548492889, 'lngE7': -15638990},
#       {'latE7': 547895622, 'lngE7': -15969469},
#       {'latE7': 547807502, 'lngE7': -15719858},
#       {'latE7': 547789726, 'lngE7': -15726164}]},
#     'simplifiedRawPath': {'points': [{'latE7': 547807465,
#        'lngE7': -15719788,
#        'timestampMs': '1638387532063',
#        'accuracyMeters': 20}]},
#     'parkingEvent': {'timestampMs': '1638387634730',
#      'location': {'latitudeE7': 547812706,
#       'longitudeE7': -15724964,
#       'accuracyMetres': 63}}}},
#   {'placeVisit': {'location': {'latitudeE7': 547783211,
#      'longitudeE7': -15730091,
#      'placeId': 'ChIJl46Wf2KHfkgR-bFewV9JUmo',
#      'address': 'Christchurch Durham\nClaypath\nDurham\nDH1 1RH\nUK',
#      'name': 'Christchurch Durham',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 98.077415},
#     'duration': {'startTimestampMs': '1638387773077',
#      'endTimestampMs': '1638395863704'},
#     'placeConfidence': 'LOW_CONFIDENCE',
#     'centerLatE7': 547784155,
#     'centerLngE7': -15729738,
#     'visitConfidence': 96,
#     'otherCandidateLocations': [{'latitudeE7': 547780556,
#       'longitudeE7': -15730556,
#       'placeId': 'ChIJeWSDeIl9fkgRpAvSCIyKtdk',
#       'locationConfidence': 0.09456043},
#      {'latitudeE7': 547784500,
#       'longitudeE7': -15713070,
#       'placeId': 'ChIJ6W4NA4l9fkgRfM-EIdOmvL4',
#       'locationConfidence': 0.08128188},
#      {'latitudeE7': 547768310,
#       'longitudeE7': -15737080,
#       'placeId': 'ChIJxbW4Lop9fkgRjUvCes7nd8w',
#       'locationConfidence': 0.073341355},
#      {'latitudeE7': 547778010,
#       'longitudeE7': -15742230,
#       'placeId': 'ChIJcVMpeYl9fkgRcZOhQgSQ3SA',
#       'locationConfidence': 0.06971398}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 547789581,
#      'longitudeE7': -15725592,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548495514,
#      'longitudeE7': -15644482,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638395863704',
#      'endTimestampMs': '1638396832241'},
#     'distance': 8093,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 97.26060032844543},
#      {'activityType': 'WALKING', 'probability': 1.284319907426834},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.8636138401925564},
#      {'activityType': 'CYCLING', 'probability': 0.19188347505405545},
#      {'activityType': 'STILL', 'probability': 0.18118034349754453},
#      {'activityType': 'IN_BUS', 'probability': 0.1180739258415997},
#      {'activityType': 'RUNNING', 'probability': 0.025227083824574947},
#      {'activityType': 'IN_FERRY', 'probability': 0.023108279856387526},
#      {'activityType': 'FLYING', 'probability': 0.02241918264189735},
#      {'activityType': 'IN_TRAIN', 'probability': 0.016423931811004877},
#      {'activityType': 'SKIING', 'probability': 0.007220415136544034},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.003467303395154886},
#      {'activityType': 'SAILING', 'probability': 0.0018569820895208977},
#      {'activityType': 'IN_TRAM', 'probability': 0.0006084776487114141},
#      {'activityType': 'IN_VEHICLE', 'probability': 5.58722845767079e-08}],
#     'simplifiedRawPath': {'points': [{'latE7': 548502053,
#        'lngE7': -15624927,
#        'timestampMs': '1638396711524',
#        'accuracyMeters': 48}]},
#     'parkingEvent': {'timestampMs': '1638396800351',
#      'location': {'latitudeE7': 548497241,
#       'longitudeE7': -15639316,
#       'accuracyMetres': 58}}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.70587},
#     'duration': {'startTimestampMs': '1638396832241',
#      'endTimestampMs': '1638466430828'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548494983,
#     'centerLngE7': -15644446,
#     'visitConfidence': 93,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.8205356},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.09597826},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.09562531},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.09145726}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548495465,
#      'longitudeE7': -15644466,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 547783954,
#      'longitudeE7': -15722962,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638466430828',
#      'endTimestampMs': '1638467523595'},
#     'distance': 8407,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 90.58740735054016},
#      {'activityType': 'WALKING', 'probability': 8.217036724090576},
#      {'activityType': 'IN_BUS', 'probability': 0.3525771899148822},
#      {'activityType': 'CYCLING', 'probability': 0.24021004792302847},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.21991366520524025},
#      {'activityType': 'STILL', 'probability': 0.16700993292033672},
#      {'activityType': 'RUNNING', 'probability': 0.10977790225297213},
#      {'activityType': 'IN_FERRY', 'probability': 0.029660703148692846},
#      {'activityType': 'FLYING', 'probability': 0.021166764781810343},
#      {'activityType': 'IN_TRAIN', 'probability': 0.019394891569390893},
#      {'activityType': 'IN_TRAM', 'probability': 0.015561618783976883},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.012294977204874158},
#      {'activityType': 'SKIING', 'probability': 0.005189272269490175},
#      {'activityType': 'SAILING', 'probability': 0.002802250128297601},
#      {'activityType': 'IN_VEHICLE', 'probability': 2.1420449858311486e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 548496475, 'lngE7': -15644766},
#       {'latE7': 547923660, 'lngE7': -15973488},
#       {'latE7': 547785491, 'lngE7': -15651061},
#       {'latE7': 547787055, 'lngE7': -15650558},
#       {'latE7': 547783889, 'lngE7': -15723383}]},
#     'simplifiedRawPath': {'points': [{'latE7': 547784538,
#        'lngE7': -15647855,
#        'timestampMs': '1638467225000',
#        'accuracyMeters': 8}]},
#     'parkingEvent': {'timestampMs': '1638467402688',
#      'location': {'latitudeE7': 547786752,
#       'longitudeE7': -15677961,
#       'accuracyMetres': 102}}}},
#   {'placeVisit': {'location': {'latitudeE7': 547783211,
#      'longitudeE7': -15730091,
#      'placeId': 'ChIJl46Wf2KHfkgR-bFewV9JUmo',
#      'address': 'Christchurch Durham\nClaypath\nDurham\nDH1 1RH\nUK',
#      'name': 'Christchurch Durham',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.84609},
#     'duration': {'startTimestampMs': '1638467523595',
#      'endTimestampMs': '1638481468882'},
#     'placeConfidence': 'LOW_CONFIDENCE',
#     'centerLatE7': 547783340,
#     'centerLngE7': -15729670,
#     'visitConfidence': 96,
#     'otherCandidateLocations': [{'latitudeE7': 547784500,
#       'longitudeE7': -15713070,
#       'placeId': 'ChIJ6W4NA4l9fkgRfM-EIdOmvL4',
#       'locationConfidence': 0.19852011},
#      {'latitudeE7': 547780556,
#       'longitudeE7': -15730556,
#       'placeId': 'ChIJeWSDeIl9fkgRpAvSCIyKtdk',
#       'locationConfidence': 0.09193213},
#      {'latitudeE7': 547768310,
#       'longitudeE7': -15737080,
#       'placeId': 'ChIJxbW4Lop9fkgRjUvCes7nd8w',
#       'locationConfidence': 0.0839348},
#      {'latitudeE7': 547778010,
#       'longitudeE7': -15742230,
#       'placeId': 'ChIJcVMpeYl9fkgRcZOhQgSQ3SA',
#       'locationConfidence': 0.04247407}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 547784571,
#      'longitudeE7': -15723956,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548495539,
#      'longitudeE7': -15644485,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638481468882',
#      'endTimestampMs': '1638482443751'},
#     'distance': 10206,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 97.55401611328125},
#      {'activityType': 'WALKING', 'probability': 1.484690047800541},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.3102619433775544},
#      {'activityType': 'CYCLING', 'probability': 0.20364262163639069},
#      {'activityType': 'STILL', 'probability': 0.18679456552490592},
#      {'activityType': 'IN_BUS', 'probability': 0.16968545969575644},
#      {'activityType': 'RUNNING', 'probability': 0.030466882162727416},
#      {'activityType': 'IN_FERRY', 'probability': 0.01623999996809289},
#      {'activityType': 'FLYING', 'probability': 0.012982881162315607},
#      {'activityType': 'IN_TRAIN', 'probability': 0.01183272761409171},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.009344396676169708},
#      {'activityType': 'SKIING', 'probability': 0.004355913188192062},
#      {'activityType': 'IN_TRAM', 'probability': 0.003974831270170398},
#      {'activityType': 'SAILING', 'probability': 0.0017105003280448727},
#      {'activityType': 'IN_VEHICLE', 'probability': 2.006281807354071e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 547784614, 'lngE7': -15723816},
#       {'latE7': 548619804, 'lngE7': -15679106},
#       {'latE7': 548496475, 'lngE7': -15644773}]},
#     'parkingEvent': {'timestampMs': '1638482494687',
#      'location': {'latitudeE7': 548495601,
#       'longitudeE7': -15644538,
#       'accuracyMetres': 25}}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 98.05619},
#     'duration': {'startTimestampMs': '1638482443751',
#      'endTimestampMs': '1638517061294'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548495477,
#     'centerLngE7': -15644757,
#     'visitConfidence': 94,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.9750883},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.12854436},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.06142813},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.046900872}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548493106,
#      'longitudeE7': -15642500,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548500820,
#      'longitudeE7': -15624314,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638517061294',
#      'endTimestampMs': '1638517230211'},
#     'distance': 144,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 96.2159276008606},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 2.6006652042269707},
#      {'activityType': 'CYCLING', 'probability': 0.3367041237652302},
#      {'activityType': 'STILL', 'probability': 0.32231786753982306},
#      {'activityType': 'RUNNING', 'probability': 0.23344308137893677},
#      {'activityType': 'IN_BUS', 'probability': 0.22709784097969532},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.03491723909974098},
#      {'activityType': 'IN_TRAIN', 'probability': 0.006039970685378648},
#      {'activityType': 'FLYING', 'probability': 0.005767625407315791},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.005382384551921859},
#      {'activityType': 'IN_TRAM', 'probability': 0.004716880721389316},
#      {'activityType': 'IN_FERRY', 'probability': 0.004640192855731584},
#      {'activityType': 'SKIING', 'probability': 0.0018866270693251863},
#      {'activityType': 'SAILING', 'probability': 0.0004964704658050323},
#      {'activityType': 'IN_VEHICLE', 'probability': 7.617338704246635e-09}],
#     'waypointPath': {'waypoints': [{'latE7': 548492355, 'lngE7': -15641870},
#       {'latE7': 548497200, 'lngE7': -15634688},
#       {'latE7': 548498954, 'lngE7': -15627461}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495508,
#      'longitudeE7': -15607875,
#      'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#      'address': 'Chester-le-Street\nDH3 3SH\nUK',
#      'name': 'Emirates Riverside',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 37.105457},
#     'duration': {'startTimestampMs': '1638517230211',
#      'endTimestampMs': '1638521449167'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'childVisits': [{'location': {'latitudeE7': 548499740,
#        'longitudeE7': -15624610,
#        'placeId': 'ChIJ0TVEBWN8fkgRFOLD0oKd_LI',
#        'address': 'County grounds\nRiverside\nBradman Dr\nChester-le-Street\nDH3 3SH\nUK',
#        'name': 'Bannatyne Health Club',
#        'sourceInfo': {'deviceTag': -1155862105},
#        'locationConfidence': 89.565765},
#       'duration': {'startTimestampMs': '1638517230211',
#        'endTimestampMs': '1638521449167'},
#       'placeConfidence': 'MEDIUM_CONFIDENCE',
#       'centerLatE7': 548500919,
#       'centerLngE7': -15624066,
#       'visitConfidence': 89,
#       'otherCandidateLocations': [{'latitudeE7': 548537302,
#         'longitudeE7': -15620971,
#         'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#         'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#         'name': 'Riverside Park',
#         'locationConfidence': 0.22295597},
#        {'latitudeE7': 548487020,
#         'longitudeE7': -15604070,
#         'placeId': 'ChIJxU9Gv2J8fkgREE_zNjv5p7g',
#         'locationConfidence': 0.113865554},
#        {'latitudeE7': 548488569,
#         'longitudeE7': -15623438,
#         'placeId': 'ChIJo8fPrmN8fkgRnZ7w6GU93M4',
#         'locationConfidence': 0.09831505},
#        {'latitudeE7': 548508015,
#         'longitudeE7': -15628304,
#         'placeId': 'ChIJF2yiPWN8fkgR2waKUsXJZzc',
#         'locationConfidence': 0.029078439}],
#       'editConfirmationStatus': 'NOT_CONFIRMED'}],
#     'centerLatE7': 548500833,
#     'centerLngE7': -15624129,
#     'visitConfidence': 89,
#     'otherCandidateLocations': [{'latitudeE7': 548495636,
#       'longitudeE7': -15644428,
#       'placeId': 'ChIJv6-je2N8fkgR7qF4kN85X8M',
#       'semanticType': 'TYPE_HOME',
#       'locationConfidence': 9.788379},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.6284272},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.35700133},
#      {'latitudeE7': 548513100,
#       'longitudeE7': -15623900,
#       'placeId': 'ChIJOVqgJWN8fkgRKUm8IVBlrHM',
#       'locationConfidence': 0.2832974}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548500659,
#      'longitudeE7': -15624265,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548496659,
#      'longitudeE7': -15646800,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638521449167',
#      'endTimestampMs': '1638521587363'},
#     'distance': 156,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 98.16240668296814},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 1.048500556498766},
#      {'activityType': 'CYCLING', 'probability': 0.3227211767807603},
#      {'activityType': 'STILL', 'probability': 0.211974885314703},
#      {'activityType': 'RUNNING', 'probability': 0.0828612654004246},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.07435576990246773},
#      {'activityType': 'IN_BUS', 'probability': 0.06093635456636548},
#      {'activityType': 'IN_TRAIN', 'probability': 0.01872068241937086},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.011776477185776457},
#      {'activityType': 'FLYING', 'probability': 0.0017290773030254059},
#      {'activityType': 'IN_FERRY', 'probability': 0.001639143010834232},
#      {'activityType': 'SKIING', 'probability': 0.0014462932085734792},
#      {'activityType': 'IN_TRAM', 'probability': 0.0005877309831703315},
#      {'activityType': 'SAILING', 'probability': 0.00034667793897824595},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.1239210950808598e-09}],
#     'waypointPath': {'waypoints': [{'latE7': 548498954, 'lngE7': -15627461},
#       {'latE7': 548497200, 'lngE7': -15634688},
#       {'latE7': 548496284, 'lngE7': -15646678}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.34756},
#     'duration': {'startTimestampMs': '1638521587363',
#      'endTimestampMs': '1638560623200'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548495455,
#     'centerLngE7': -15644655,
#     'visitConfidence': 92,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.8138748},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.6971853},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.16927019},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.07806927}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548495600,
#      'longitudeE7': -15644541,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 547693139,
#      'longitudeE7': -16210382,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638560623200',
#      'endTimestampMs': '1638561604347'},
#     'distance': 10633,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 93.43452453613281},
#      {'activityType': 'MOTORCYCLING', 'probability': 4.527134075760841},
#      {'activityType': 'WALKING', 'probability': 1.3744406402111053},
#      {'activityType': 'CYCLING', 'probability': 0.41021304205060005},
#      {'activityType': 'STILL', 'probability': 0.10600644163787365},
#      {'activityType': 'IN_BUS', 'probability': 0.06326014990918338},
#      {'activityType': 'RUNNING', 'probability': 0.03823805891443044},
#      {'activityType': 'IN_FERRY', 'probability': 0.015222256479319185},
#      {'activityType': 'FLYING', 'probability': 0.011425912816775963},
#      {'activityType': 'SKIING', 'probability': 0.008947477908805013},
#      {'activityType': 'IN_TRAIN', 'probability': 0.006256291817408055},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.0024253200535895303},
#      {'activityType': 'SAILING', 'probability': 0.0017996828319155611},
#      {'activityType': 'IN_TRAM', 'probability': 9.888595968732261e-05},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.0775050990341484e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 548496475, 'lngE7': -15644805},
#       {'latE7': 548520202, 'lngE7': -15618436},
#       {'latE7': 547692985, 'lngE7': -16210434}]},
#     'parkingEvent': {'timestampMs': '1638562053467',
#      'location': {'latitudeE7': 547693101,
#       'longitudeE7': -16210390,
#       'accuracyMetres': 91}}}},
#   {'placeVisit': {'location': {'latitudeE7': 547693023,
#      'longitudeE7': -16209137,
#      'placeId': 'ChIJ9QZerqiAfkgRpT3U8OvriAc',
#      'address': "9 Cooke's Wood\nBroompark\nDurham\nDH7 7RL\nUK",
#      'name': "9 Cooke's Wood",
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 81.57577},
#     'duration': {'startTimestampMs': '1638561604347',
#      'endTimestampMs': '1638572176007'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 547693089,
#     'centerLngE7': -16210454,
#     'visitConfidence': 96,
#     'otherCandidateLocations': [{'latitudeE7': 547693573,
#       'longitudeE7': -16212969,
#       'placeId': 'ChIJEYIbqaiAfkgRdXDy98mRxME',
#       'locationConfidence': 9.579514},
#      {'latitudeE7': 547693852,
#       'longitudeE7': -16206491,
#       'placeId': 'ChIJx4musaiAfkgRjO08lCguy_w',
#       'locationConfidence': 2.3781223},
#      {'latitudeE7': 547661884,
#       'longitudeE7': -16189226,
#       'placeId': 'ChIJlYoPCK-AfkgRWY_pHCs3fcU',
#       'locationConfidence': 0.3005364},
#      {'latitudeE7': 547677721,
#       'longitudeE7': -16255738,
#       'placeId': 'ChIJnUAhMaSAfkgRue7oQTgoLlQ',
#       'locationConfidence': 0.24714744}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 547698348,
#      'longitudeE7': -16202956,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548495916,
#      'longitudeE7': -15645962,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638572176007',
#      'endTimestampMs': '1638573025247'},
#     'distance': 10574,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 97.72789478302002},
#      {'activityType': 'WALKING', 'probability': 1.081913523375988},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.4881185479462147},
#      {'activityType': 'CYCLING', 'probability': 0.40892348624765873},
#      {'activityType': 'IN_BUS', 'probability': 0.09964047931134701},
#      {'activityType': 'STILL', 'probability': 0.09544446365907788},
#      {'activityType': 'RUNNING', 'probability': 0.029491409077309072},
#      {'activityType': 'IN_FERRY', 'probability': 0.025827932404354215},
#      {'activityType': 'FLYING', 'probability': 0.011461559915915132},
#      {'activityType': 'IN_TRAIN', 'probability': 0.011260787141509354},
#      {'activityType': 'SKIING', 'probability': 0.01052232037181966},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.004940160215483047},
#      {'activityType': 'IN_TRAM', 'probability': 0.0024651908461237326},
#      {'activityType': 'SAILING', 'probability': 0.0021033705706940964},
#      {'activityType': 'IN_VEHICLE', 'probability': 4.4645797475650895e-09}],
#     'waypointPath': {'waypoints': [{'latE7': 547698135, 'lngE7': -16203130},
#       {'latE7': 548522949, 'lngE7': -15619926},
#       {'latE7': 548496322, 'lngE7': -15646091}]},
#     'parkingEvent': {'timestampMs': '1638573095593',
#      'location': {'latitudeE7': 548495676,
#       'longitudeE7': -15645068,
#       'accuracyMetres': 33}}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 98.96484},
#     'duration': {'startTimestampMs': '1638573025247',
#      'endTimestampMs': '1638609720532'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548495853,
#     'centerLngE7': -15645791,
#     'visitConfidence': 94,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.63289905},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.09602202},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.061815012},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.04473875}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548495480,
#      'longitudeE7': -15644495,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 549130116,
#      'longitudeE7': -13708069,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638609720532',
#      'endTimestampMs': '1638612254223'},
#     'distance': 16247,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 95.9801733493805},
#      {'activityType': 'WALKING', 'probability': 2.7034450322389603},
#      {'activityType': 'STILL', 'probability': 0.6162191741168499},
#      {'activityType': 'CYCLING', 'probability': 0.24186570663005114},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.20643880125135183},
#      {'activityType': 'IN_BUS', 'probability': 0.11185689363628626},
#      {'activityType': 'RUNNING', 'probability': 0.0655081938020885},
#      {'activityType': 'IN_FERRY', 'probability': 0.02682982594706118},
#      {'activityType': 'FLYING', 'probability': 0.02334584278287366},
#      {'activityType': 'IN_TRAIN', 'probability': 0.007625374564668164},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.0056190361647168174},
#      {'activityType': 'SKIING', 'probability': 0.005032913395552896},
#      {'activityType': 'IN_TRAM', 'probability': 0.003482891042949632},
#      {'activityType': 'SAILING', 'probability': 0.002554074308136478},
#      {'activityType': 'IN_VEHICLE', 'probability': 9.287618674136411e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 548496475, 'lngE7': -15644793},
#       {'latE7': 548619041, 'lngE7': -15687234},
#       {'latE7': 549133224, 'lngE7': -13715320}]},
#     'parkingEvent': {'timestampMs': '1638612039971',
#      'location': {'latitudeE7': 549128957,
#       'longitudeE7': -13707196,
#       'accuracyMetres': 88}}}},
#   {'placeVisit': {'location': {'latitudeE7': 549125708,
#      'longitudeE7': -13706578,
#      'placeId': 'ChIJOZU-l0NmfkgROo1hGGIqQOc',
#      'address': 'Roker Terrace\nRoker\nSunderland\nSR6 9NB\nUK',
#      'name': 'Glass Centre, Sunderland, UK',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 55.006905},
#     'duration': {'startTimestampMs': '1638612254223',
#      'endTimestampMs': '1638614860145'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 549129794,
#     'centerLngE7': -13705903,
#     'visitConfidence': 96,
#     'otherCandidateLocations': [{'latitudeE7': 549116800,
#       'longitudeE7': -13743030,
#       'placeId': 'ChIJI4hfbWFmfkgRdNSbQBeKrKo',
#       'locationConfidence': 35.288273},
#      {'latitudeE7': 549134548,
#       'longitudeE7': -13740565,
#       'placeId': 'ChIJNZ5M52BmfkgRUu8SqWBgTQU',
#       'locationConfidence': 0.7636825},
#      {'latitudeE7': 549128897,
#       'longitudeE7': -13710681,
#       'placeId': 'ChIJUYNnKF5mfkgRYnSNArDOh80',
#       'locationConfidence': 0.45609772},
#      {'latitudeE7': 549119507,
#       'longitudeE7': -13665254,
#       'placeId': 'ChIJcfbanYpmfkgRXNXw6OasIYI',
#       'locationConfidence': 0.08685487}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 549128403,
#      'longitudeE7': -13707239,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 549109036,
#      'longitudeE7': -15461353,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638614860145',
#      'endTimestampMs': '1638616311998'},
#     'distance': 11740,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 96.9203770160675},
#      {'activityType': 'WALKING', 'probability': 1.36541947722435},
#      {'activityType': 'STILL', 'probability': 0.6023602094501257},
#      {'activityType': 'CYCLING', 'probability': 0.426249485462904},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.16444940119981766},
#      {'activityType': 'IN_BUS', 'probability': 0.15542862238362432},
#      {'activityType': 'IN_FERRY', 'probability': 0.13796647544950247},
#      {'activityType': 'RUNNING', 'probability': 0.10955872712656856},
#      {'activityType': 'FLYING', 'probability': 0.044663730659522116},
#      {'activityType': 'IN_TRAM', 'probability': 0.027744946419261396},
#      {'activityType': 'SKIING', 'probability': 0.017952117195818573},
#      {'activityType': 'SAILING', 'probability': 0.010203484271187335},
#      {'activityType': 'IN_TRAIN', 'probability': 0.009789393516257405},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.00783378491178155},
#      {'activityType': 'IN_VEHICLE', 'probability': 7.375415833621446e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 549124412, 'lngE7': -13711452},
#       {'latE7': 549055557, 'lngE7': -14968979},
#       {'latE7': 549108352, 'lngE7': -15458830}]},
#     'parkingEvent': {'timestampMs': '1638616295106',
#      'location': {'latitudeE7': 549106094,
#       'longitudeE7': -15437891,
#       'accuracyMetres': 70}}}},
#   {'placeVisit': {'location': {'latitudeE7': 549106639,
#      'longitudeE7': -15465224,
#      'placeId': 'ChIJtwSFouJ6fkgR_mrnqes2ZHQ',
#      'address': 'Armstrong Industrial Estate\nWashington\nNE37 1LH\nUK',
#      'name': 'B&Q Washington',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 95.24475},
#     'duration': {'startTimestampMs': '1638616311998',
#      'endTimestampMs': '1638616819000'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 549109560,
#     'centerLngE7': -15460740,
#     'visitConfidence': 95,
#     'otherCandidateLocations': [{'latitudeE7': 549100070,
#       'longitudeE7': -15473760,
#       'placeId': 'ChIJ8QVf2OJ6fkgRXchr8Sx8hNM',
#       'locationConfidence': 2.15323},
#      {'latitudeE7': 549101606,
#       'longitudeE7': -15472933,
#       'placeId': 'ChIJg_9PJ-N6fkgRSE4ikjOCvF0',
#       'locationConfidence': 0.31265905},
#      {'latitudeE7': 549092480,
#       'longitudeE7': -15439220,
#       'placeId': 'ChIJgVLUT-J6fkgR162U08ikbOU',
#       'locationConfidence': 0.08665815},
#      {'latitudeE7': 549087318,
#       'longitudeE7': -15492813,
#       'placeId': 'ChIJaxq0OP16fkgRZ64kKhXwfP8',
#       'locationConfidence': 0.02540559}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 549114814,
#      'longitudeE7': -15448185,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548495451,
#      'longitudeE7': -15644467,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638616819000',
#      'endTimestampMs': '1638617403123'},
#     'distance': 7290,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 97.60748147964478},
#      {'activityType': 'WALKING', 'probability': 1.326796319335699},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.3623449010774493},
#      {'activityType': 'CYCLING', 'probability': 0.314405164681375},
#      {'activityType': 'STILL', 'probability': 0.23097831290215254},
#      {'activityType': 'IN_FERRY', 'probability': 0.04379307210911065},
#      {'activityType': 'RUNNING', 'probability': 0.03672259917948395},
#      {'activityType': 'IN_BUS', 'probability': 0.03641194780357182},
#      {'activityType': 'SKIING', 'probability': 0.0180718008778058},
#      {'activityType': 'FLYING', 'probability': 0.012960458116140217},
#      {'activityType': 'IN_TRAIN', 'probability': 0.004764168625115417},
#      {'activityType': 'SAILING', 'probability': 0.002776761721179355},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.0013459456567943562},
#      {'activityType': 'IN_TRAM', 'probability': 0.0011456707397883292},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.0353574247945474e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 549114036, 'lngE7': -15448478},
#       {'latE7': 548619804, 'lngE7': -15679106},
#       {'latE7': 548496475, 'lngE7': -15644778}]},
#     'parkingEvent': {'timestampMs': '1638617479193',
#      'location': {'latitudeE7': 548495294,
#       'longitudeE7': -15644367,
#       'accuracyMetres': 25}}}},
#   {'placeVisit': {'location': {'latitudeE7': 548495376,
#      'longitudeE7': -15645027,
#      'placeId': 'ChIJ7wseeWN8fkgRRxsCcsHpCZU',
#      'address': '14 Milburn Close, Chester-le-Street DH3 3QT, UK',
#      'name': '14 Milburn Cl',
#      'semanticType': 'TYPE_HOME',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.54463},
#     'duration': {'startTimestampMs': '1638617403123',
#      'endTimestampMs': '1638635779950'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 548495626,
#     'centerLngE7': -15643608,
#     'visitConfidence': 94,
#     'otherCandidateLocations': [{'latitudeE7': 548497523,
#       'longitudeE7': -15645499,
#       'placeId': 'ChIJv6-je2N8fkgRDmwY9uIfjMQ',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.94525766},
#      {'latitudeE7': 548537302,
#       'longitudeE7': -15620971,
#       'placeId': 'ChIJK2Of4Xx8fkgRIjhJ08fe3hc',
#       'address': 'Ropery Ln,Chester-le-Street, Durham\nChester-le-Street\nDH3 3PL\nUK',
#       'name': 'Riverside Park',
#       'locationConfidence': 0.119639374},
#      {'latitudeE7': 548495508,
#       'longitudeE7': -15607875,
#       'placeId': 'ChIJNxTeUmR8fkgR3Ld2Fvyd7Qw',
#       'address': 'Chester-le-Street\nDH3 3SH\nUK',
#       'name': 'Emirates Riverside',
#       'locationConfidence': 0.11244435},
#      {'latitudeE7': 548518729,
#       'longitudeE7': -15630523,
#       'placeId': 'ChIJr0emM2N8fkgRWTe0J3c61V8',
#       'locationConfidence': 0.03829048}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 548495488,
#      'longitudeE7': -15644496,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 548613738,
#      'longitudeE7': -15691056,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1638635779950',
#      'endTimestampMs': '1638636122936'},
#     'distance': 1351,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 87.82554864883423},
#      {'activityType': 'WALKING', 'probability': 8.949220180511475},
#      {'activityType': 'CYCLING', 'probability': 1.3282145373523235},
#      {'activityType': 'STILL', 'probability': 1.0865213349461555},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.37767207249999046},
#      {'activityType': 'RUNNING', 'probability': 0.2843386959284544},
#      {'activityType': 'IN_BUS', 'probability': 0.05449575837701559},
#      {'activityType': 'IN_FERRY', 'probability': 0.036036226083524525},
#      {'activityType': 'SKIING', 'probability': 0.028124329401180148},
#      {'activityType': 'FLYING', 'probability': 0.010215427028015256},
#      {'activityType': 'IN_TRAM', 'probability': 0.006746270082658157},
#      {'activityType': 'SAILING', 'probability': 0.006324443529592827},
#      {'activityType': 'IN_TRAIN', 'probability': 0.0037216395867289975},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.0028261045372346416},
#      {'activityType': 'IN_VEHICLE', 'probability': 2.0915778831120946e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 548496475, 'lngE7': -15644793},
#       {'latE7': 548518600, 'lngE7': -15653841},
#       {'latE7': 548615036, 'lngE7': -15693855}]},
#     'parkingEvent': {'timestampMs': '1638636092438',
#      'location': {'latitudeE7': 548612501,
#       'longitudeE7': -15689640,
#       'accuracyMetres': 71}}}},
#   {'placeVisit': {'location': {'latitudeE7': 548613733,
#      'longitudeE7': -15692098,
#      'placeId': 'ChIJd0uK9Xh8fkgRD9CPCXAwN3A',
#      'address': 'Park Road BP\nPark Rd N\nStirling Road\nChester-le-Street\nDH3 3SU\nUK',
#      'name': 'M&S Simply Food',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 92.74672},
#     'duration': {'startTimestampMs': '1638636122936',
#      'endTimestampMs': '1638636435389'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'childVisits': [{'location': {'latitudeE7': 548614810,
#        'longitudeE7': -15688850,
#        'placeId': 'ChIJZwX09Hh8fkgRYfqigLiz5wE',
#        'address': 'Park Rd N\nChester-le-Street\nDH3 3SU\nUK',
#        'name': 'bp',
#        'sourceInfo': {'deviceTag': -1155862105},
#        'locationConfidence': 82.42779},
#       'duration': {'startTimestampMs': '1638636122936',
#        'endTimestampMs': '1638636435389'},
# ...
#      {'activityType': 'IN_TRAIN', 'probability': 1.1021995916962624},
#      {'activityType': 'STILL', 'probability': 0.7139242254197598},
#      {'activityType': 'CYCLING', 'probability': 0.6800289265811443},
#      {'activityType': 'RUNNING', 'probability': 0.25888450909405947},
#      {'activityType': 'IN_FERRY', 'probability': 0.07357287686318159},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.05913079367019236},
#      {'activityType': 'FLYING', 'probability': 0.013136213237885386},
#      {'activityType': 'SAILING', 'probability': 0.001956918276846409},
#      {'activityType': 'SKIING', 'probability': 0.0006890812983328942},
#      {'activityType': 'IN_VEHICLE', 'probability': 4.312742607481823e-07}],
#     'simplifiedRawPath': {'points': [{'latE7': 559524271,
#        'lngE7': -31968581,
#        'timestampMs': '1640869527221',
#        'accuracyMeters': 15},
#       {'latE7': 559518825,
#        'lngE7': -31975385,
#        'timestampMs': '1640869648310',
#        'accuracyMeters': 35},
#       {'latE7': 559500302,
#        'lngE7': -32080246,
#        'timestampMs': '1640869769488',
#        'accuracyMeters': 24},
#       {'latE7': 559476905,
#        'lngE7': -32139648,
#        'timestampMs': '1640869890567',
#        'accuracyMeters': 37}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 559280749,
#      'longitudeE7': -33081929,
#      'placeId': 'ChIJYwMryTHEh0gRJOrBQn5Hb2w',
#      'address': '1 Lochside Ct\nEdinburgh\nEH12 9FX\nUK',
#      'name': 'Premier Inn Edinburgh Park (Airport) hotel',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 64.29862},
#     'duration': {'startTimestampMs': '1640870744397',
#      'endTimestampMs': '1640871479336'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 559314364,
#     'centerLngE7': -33114825,
#     'visitConfidence': 87,
#     'otherCandidateLocations': [{'latitudeE7': 559276646,
#       'longitudeE7': -33078331,
#       'placeId': 'ChIJZ8Z7SjDEh0gRi3KkGbrDaZ4',
#       'locationConfidence': 22.408802},
#      {'latitudeE7': 559273767,
#       'longitudeE7': -33070226,
#       'placeId': 'ChIJi2bNMzDEh0gR0waSLb1yjT0',
#       'locationConfidence': 10.097766},
#      {'latitudeE7': 559266110,
#       'longitudeE7': -33111349,
#       'placeId': 'ChIJGQL96zDEh0gRyhvExkO2PLI',
#       'locationConfidence': 1.1002562},
#      {'latitudeE7': 559262014,
#       'longitudeE7': -33075083,
#       'placeId': 'ChIJpylGFEfFh0gRIuVQUZGr0NQ',
#       'locationConfidence': 0.43220007}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 559314364,
#      'longitudeE7': -33114825,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 550611007,
#      'longitudeE7': -36623418,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1640871479336',
#      'endTimestampMs': '1640878316000'},
#     'distance': 100846,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 94.79849338531494},
#      {'activityType': 'STILL', 'probability': 2.0857026800513268},
#      {'activityType': 'IN_BUS', 'probability': 1.6002532094717026},
#      {'activityType': 'WALKING', 'probability': 0.7543833460658789},
#      {'activityType': 'IN_TRAM', 'probability': 0.28831956442445517},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.14864883851259947},
#      {'activityType': 'CYCLING', 'probability': 0.12839147821068764},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.07779579609632492},
#      {'activityType': 'IN_FERRY', 'probability': 0.03926194040104747},
#      {'activityType': 'RUNNING', 'probability': 0.03039519360754639},
#      {'activityType': 'IN_TRAIN', 'probability': 0.021381753322202712},
#      {'activityType': 'FLYING', 'probability': 0.0202306589926593},
#      {'activityType': 'SKIING', 'probability': 0.004527217606664635},
#      {'activityType': 'SAILING', 'probability': 0.0022072741558076814},
#      {'activityType': 'IN_VEHICLE', 'probability': 3.556940741944459e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 559314842, 'lngE7': -33112456},
#       {'latE7': 559346809, 'lngE7': -33077564},
#       {'latE7': 559368133, 'lngE7': -33135635},
#       {'latE7': 550784072, 'lngE7': -36249072},
#       {'latE7': 550609283, 'lngE7': -36622817}]},
#     'simplifiedRawPath': {'points': [{'latE7': 559368439,
#        'lngE7': -33137064,
#        'timestampMs': '1640871849540',
#        'accuracyMeters': 82}]},
#     'parkingEvent': {'timestampMs': '1640878332755',
#      'location': {'latitudeE7': 550611062,
#       'longitudeE7': -36624232,
#       'accuracyMetres': 30}}}},
#   {'placeVisit': {'location': {'latitudeE7': 550612034,
#      'longitudeE7': -36630184,
#      'placeId': 'ChIJzVIG1urJYkgRS5VnCEGPLWY',
#      'address': 'The Old Glen Road\nDumfries\nDG2 8PT\nUK',
#      'name': 'Kilnford Farm Shop and Farmhouse Kitchen Cafe',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 97.091156},
#     'duration': {'startTimestampMs': '1640878316000',
#      'endTimestampMs': '1640878811181'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 550611317,
#     'centerLngE7': -36628667,
#     'visitConfidence': 95,
#     'otherCandidateLocations': [{'latitudeE7': 550628833,
#       'longitudeE7': -36664949,
#       'placeId': 'ChIJ47un9urJYkgRjDE72wDC5A0',
#       'locationConfidence': 0.790653},
#      {'latitudeE7': 550608209,
#       'longitudeE7': -36649316,
#       'placeId': 'ChIJM60H1urJYkgR1QUdZTF5rek',
#       'locationConfidence': 0.25832248}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 550611414,
#      'longitudeE7': -36629959,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 549370328,
#      'longitudeE7': -39237032,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1640878811181',
#      'endTimestampMs': '1640880517000'},
#     'distance': 24277,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 98.7909734249115},
#      {'activityType': 'WALKING', 'probability': 0.6289137061685324},
#      {'activityType': 'STILL', 'probability': 0.3128434531390667},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.12866334291175008},
#      {'activityType': 'CYCLING', 'probability': 0.06277186912484467},
#      {'activityType': 'RUNNING', 'probability': 0.02139778225682676},
#      {'activityType': 'IN_BUS', 'probability': 0.018043928139377385},
#      {'activityType': 'IN_FERRY', 'probability': 0.01786087959771976},
#      {'activityType': 'FLYING', 'probability': 0.008603002788731828},
#      {'activityType': 'SKIING', 'probability': 0.003863847450702451},
#      {'activityType': 'IN_TRAIN', 'probability': 0.0024395996661041863},
#      {'activityType': 'SAILING', 'probability': 0.0016260864867945202},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.00123144818644505},
#      {'activityType': 'IN_TRAM', 'probability': 0.0007553162504336797},
#      {'activityType': 'IN_VEHICLE', 'probability': 4.131456565747982e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 550610847, 'lngE7': -36632070},
#       {'latE7': 549580421, 'lngE7': -39177258},
#       {'latE7': 549370346, 'lngE7': -39236853}]},
#     'parkingEvent': {'timestampMs': '1640880601074',
#      'location': {'latitudeE7': 549373068,
#       'longitudeE7': -39239258,
#       'accuracyMetres': 28}}}},
#   {'placeVisit': {'location': {'latitudeE7': 549372323,
#      'longitudeE7': -39242919,
#      'placeId': 'ChIJTZWtOvfCYkgR53W8aJmD5Sc',
#      'address': '36 Queen Elizabeth Dr\nCastle Douglas\nDG7 1HH\nUK',
#      'name': '36 Queen Elizabeth Dr',
#      'semanticType': 'TYPE_SEARCHED_ADDRESS',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 95.994934},
#     'duration': {'startTimestampMs': '1640880517000',
#      'endTimestampMs': '1640955334810'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 549372389,
#     'centerLngE7': -39241959,
#     'visitConfidence': 95,
#     'otherCandidateLocations': [{'latitudeE7': 549370880,
#       'longitudeE7': -39235770,
#       'placeId': 'ChIJzRiuN_fCYkgRu2-nqw7KOs4',
#       'locationConfidence': 0.24328779},
#      {'latitudeE7': 549308468,
#       'longitudeE7': -39319323,
#       'placeId': 'ChIJuZYLgvLCYkgRna6fr_LCYkg',
#       'locationConfidence': 0.12355377},
#      {'latitudeE7': 549370193,
#       'longitudeE7': -39277024,
#       'placeId': 'ChIJj3JxTPTCYkgRDVQtVX3mW6s',
#       'locationConfidence': 0.027128885},
#      {'latitudeE7': 549389407,
#       'longitudeE7': -39248998,
#       'placeId': 'ChIJraF-DJDmYkgR1zIvnXoBfvA',
#       'locationConfidence': 0.02225202}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 549372986,
#      'longitudeE7': -39239721,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 549387956,
#      'longitudeE7': -39312050,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1640955334810',
#      'endTimestampMs': '1640955968775'},
#     'distance': 519,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 97.30819463729858},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 1.7273593693971634},
#      {'activityType': 'CYCLING', 'probability': 0.26674435939639807},
#      {'activityType': 'IN_BUS', 'probability': 0.21656930912286043},
#      {'activityType': 'RUNNING', 'probability': 0.204025162383914},
#      {'activityType': 'STILL', 'probability': 0.13076046016067266},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.03956969303544611},
#      {'activityType': 'IN_FERRY', 'probability': 0.02846628485713154},
#      {'activityType': 'IN_TRAM', 'probability': 0.020382444199640304},
#      {'activityType': 'SKIING', 'probability': 0.016601342940703034},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.01647657190915197},
#      {'activityType': 'IN_TRAIN', 'probability': 0.016348090139217675},
#      {'activityType': 'FLYING', 'probability': 0.004999604061595164},
#      {'activityType': 'SAILING', 'probability': 0.003501786704873666},
#      {'activityType': 'IN_VEHICLE', 'probability': 3.5061714642736774e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 549373016, 'lngE7': -39239683},
#       {'latE7': 549385452, 'lngE7': -39309794},
#       {'latE7': 549387168, 'lngE7': -39313290}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 549396855,
#      'longitudeE7': -39313014,
#      'placeId': 'ChIJy69jt_XCYkgRH-kXd0GnsM4',
#      'address': '184-186 King St\nCastle Douglas\nDG7 1DA\nUK',
#      'name': 'The Scottish Pantry',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 86.00195},
#     'duration': {'startTimestampMs': '1640955968775',
#      'endTimestampMs': '1640958529575'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 549396450,
#     'centerLngE7': -39312138,
#     'visitConfidence': 92,
#     'otherCandidateLocations': [{'latitudeE7': 549387735,
#       'longitudeE7': -39316356,
#       'placeId': 'ChIJS3HzTfTCYkgR3m57mfLTxZI',
#       'locationConfidence': 1.2351248},
#      {'latitudeE7': 549394631,
#       'longitudeE7': -39310299,
#       'placeId': 'ChIJTbf7tvXCYkgRAPraQ-_MbPQ',
#       'locationConfidence': 0.89281183},
#      {'latitudeE7': 549386487,
#       'longitudeE7': -39315245,
#       'placeId': 'ChIJj3JxTPTCYkgRLfcDPlJTfkU',
#       'locationConfidence': 0.83316934},
#      {'latitudeE7': 549399090,
#       'longitudeE7': -39305054,
#       'placeId': 'ChIJJ5CCxvXCYkgRauLMj89QZ0w',
#       'locationConfidence': 0.72186023},
#      {'latitudeE7': 549393171,
#       'longitudeE7': -39313611,
#       'placeId': 'ChIJqSbos_XCYkgRVtL0xgtXMjk',
#       'locationConfidence': 0.7061472},
#      {'latitudeE7': 549394310,
#       'longitudeE7': -39312497,
#       'placeId': 'ChIJ62FEwvXCYkgR8gvkkro_lfM',
#       'locationConfidence': 0.5953546},
#      {'latitudeE7': 549397905,
#       'longitudeE7': -39311638,
#       'placeId': 'ChIJoV-W0WnDYkgRHvI_a6Xn2Rg',
#       'locationConfidence': 0.5875758},
#      {'latitudeE7': 549419069,
#       'longitudeE7': -39280077,
#       'placeId': 'ChIJdTzdm1jCYkgRT3flPxCJaf8',
#       'locationConfidence': 0.53285325},
#      {'latitudeE7': 549403373,
#       'longitudeE7': -39301162,
#       'placeId': 'ChIJuzs53fXCYkgRwp_eifFbTQc',
#       'locationConfidence': 0.514083}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 549403826,
#      'longitudeE7': -39302574,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'endLocation': {'latitudeE7': 549375693,
#      'longitudeE7': -39246981,
#      'sourceInfo': {'deviceTag': -1155862105}},
#     'duration': {'startTimestampMs': '1640958529575',
#      'endTimestampMs': '1640959500662'},
#     'distance': 921,
#     'activityType': 'WALKING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 96.6119110584259},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 1.8049560487270355},
#      {'activityType': 'STILL', 'probability': 0.48842024989426136},
#      {'activityType': 'CYCLING', 'probability': 0.47988351434469223},
#      {'activityType': 'RUNNING', 'probability': 0.35503606777638197},
#      {'activityType': 'IN_BUS', 'probability': 0.1322903437539935},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.05540978745557368},
#      {'activityType': 'SKIING', 'probability': 0.016044847143348306},
#      {'activityType': 'IN_TRAM', 'probability': 0.014431927411351353},
#      {'activityType': 'IN_FERRY', 'probability': 0.012156911543570459},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.011890727182617411},
#      {'activityType': 'IN_TRAIN', 'probability': 0.011653626279439777},
#      {'activityType': 'FLYING', 'probability': 0.0035411670978646725},
#      {'activityType': 'SAILING', 'probability': 0.0023701310055912472},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.7161847498670113e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 549403610, 'lngE7': -39302029},
#       {'latE7': 549415397, 'lngE7': -39286479},
#       {'latE7': 549419746, 'lngE7': -39259972},
#       {'latE7': 549422874, 'lngE7': -39256250},
#       {'latE7': 549415130, 'lngE7': -39256143},
#       {'latE7': 549376029, 'lngE7': -39246468}]},
#     'simplifiedRawPath': {'points': [{'latE7': 549419479,
#        'lngE7': -39259169,
#        'timestampMs': '1640958892775',
#        'accuracyMeters': 42},
#       {'latE7': 549414902,
#        'lngE7': -39254956,
#        'timestampMs': '1640959013888',
#        'accuracyMeters': 31}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 549372323,
#      'longitudeE7': -39242919,
#      'placeId': 'ChIJTZWtOvfCYkgR53W8aJmD5Sc',
#      'address': '36 Queen Elizabeth Dr\nCastle Douglas\nDG7 1HH\nUK',
#      'name': '36 Queen Elizabeth Dr',
#      'semanticType': 'TYPE_SEARCHED_ADDRESS',
#      'sourceInfo': {'deviceTag': -1155862105},
#      'locationConfidence': 96.98861},
#     'duration': {'startTimestampMs': '1640959500662',
#      'endTimestampMs': '1641043019000'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 549372200,
#     'centerLngE7': -39242700,
#     'visitConfidence': 94,
#     'otherCandidateLocations': [{'latitudeE7': 549370880,
#       'longitudeE7': -39235770,
#       'placeId': 'ChIJzRiuN_fCYkgRu2-nqw7KOs4',
#       'locationConfidence': 0.3033673},
#      {'latitudeE7': 549308468,
#       'longitudeE7': -39319323,
#       'placeId': 'ChIJuZYLgvLCYkgRna6fr_LCYkg',
#       'locationConfidence': 0.14251456},
#      {'latitudeE7': 549370193,
#       'longitudeE7': -39277024,
#       'placeId': 'ChIJj3JxTPTCYkgRDVQtVX3mW6s',
#       'locationConfidence': 0.03949586},
#      {'latitudeE7': 549396855,
#       'longitudeE7': -39313014,
#       'placeId': 'ChIJy69jt_XCYkgRH-kXd0GnsM4',
#       'address': '184-186 King St\nCastle Douglas\nDG7 1DA\nUK',
#       'name': 'The Scottish Pantry',
#       'locationConfidence': 0.037522413}],
#     'editConfirmationStatus': 'NOT_CONFIRMED'}}]}

# %%
fb
# Out:
# {'location_history_v2': [{'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.843189239502, 'longitude': -1.5784373283386},
#    'creation_timestamp': 1641492161},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.837020874023, 'longitude': -1.5891205072403},
#    'creation_timestamp': 1641491440},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.845188140869, 'longitude': -1.5736352205276},
#    'creation_timestamp': 1641490587},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849552154541, 'longitude': -1.5644272565842},
#    'creation_timestamp': 1641391009},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.8525390625, 'longitude': -1.5667251348495},
#    'creation_timestamp': 1641390041},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.856094360352, 'longitude': -1.5733011960983},
#    'creation_timestamp': 1641380066},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.854629516602, 'longitude': -1.5690437555313},
#    'creation_timestamp': 1641380006},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.84956741333, 'longitude': -1.5644277334213},
#    'creation_timestamp': 1641130363},
#   {'name': 'Annan',
#    'coordinate': {'latitude': 55.015029907227, 'longitude': -3.1952681541443},
#    'creation_timestamp': 1641122224},
#   {'name': 'Castle Douglas',
#    'coordinate': {'latitude': 54.945541381836, 'longitude': -3.9253711700439},
#    'creation_timestamp': 1641120939},
#   {'name': 'Castle Douglas',
#    'coordinate': {'latitude': 54.976764678955, 'longitude': -3.8933389186859},
#    'creation_timestamp': 1641120059},
#   {'name': 'Castle Douglas',
#    'coordinate': {'latitude': 54.937145233154, 'longitude': -3.9244582653046},
#    'creation_timestamp': 1641047267},
#   {'name': 'Castle Douglas',
#    'coordinate': {'latitude': 54.938816070557, 'longitude': -3.930775642395},
#    'creation_timestamp': 1641043064},
#   {'name': 'Castle Douglas',
#    'coordinate': {'latitude': 54.937297821045, 'longitude': -3.9244232177734},
#    'creation_timestamp': 1640880638},
#   {'name': 'Dumfries',
#    'coordinate': {'latitude': 55.084999084473, 'longitude': -3.7253882884979},
#    'creation_timestamp': 1640873547},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.935459136963, 'longitude': -3.3128082752228},
#    'creation_timestamp': 1640870879},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.937973022461, 'longitude': -3.2609655857086},
#    'creation_timestamp': 1640870011},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.953598022461, 'longitude': -3.1937925815582},
#    'creation_timestamp': 1640860906},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.941848754883, 'longitude': -3.2459833621979},
#    'creation_timestamp': 1640860222},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.928035736084, 'longitude': -3.3079700469971},
#    'creation_timestamp': 1640812381},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.934871673584, 'longitude': -3.2759373188019},
#    'creation_timestamp': 1640812321},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.950614929199, 'longitude': -3.1952257156372},
#    'creation_timestamp': 1640793667},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.941329956055, 'longitude': -3.2411525249481},
#    'creation_timestamp': 1640792876},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.927913665771, 'longitude': -3.3078103065491},
#    'creation_timestamp': 1640790398},
#   {'name': 'Edinburgh',
#    'coordinate': {'latitude': 55.912883758545, 'longitude': -3.2886846065521},
#    'creation_timestamp': 1640790152},
#   {'name': 'Berwick',
#    'coordinate': {'latitude': 55.784088134766, 'longitude': -2.0152356624603},
#    'creation_timestamp': 1640784541},
#   {'name': 'Newcastle upon Tyne',
#    'coordinate': {'latitude': 55.056125640869, 'longitude': -1.6468898057938},
#    'creation_timestamp': 1640780465},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849559783936, 'longitude': -1.5644243955612},
#    'creation_timestamp': 1640713881},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.850254058838, 'longitude': -1.5798951387405},
#    'creation_timestamp': 1640711732},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.845527648926, 'longitude': -1.6001023054123},
#    'creation_timestamp': 1640711012},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.843799591064, 'longitude': -1.5803451538086},
#    'creation_timestamp': 1640709182},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849559783936, 'longitude': -1.5644862651825},
#    'creation_timestamp': 1640628736},
#   {'name': 'Thirsk',
#    'coordinate': {'latitude': 54.247428894043, 'longitude': -1.3463853597641},
#    'creation_timestamp': 1640622197},
#   {'name': 'Pocklington',
#    'coordinate': {'latitude': 53.924938201904, 'longitude': -0.77490013837814},
#    'creation_timestamp': 1640600986},
#   {'name': 'Pocklington',
#    'coordinate': {'latitude': 53.928524017334, 'longitude': -0.80536127090454},
#    'creation_timestamp': 1640600926},
#   {'name': 'Bishopthorpe',
#    'coordinate': {'latitude': 53.921901702881, 'longitude': -1.0776751041412},
#    'creation_timestamp': 1640597508},
#   {'name': 'York',
#    'coordinate': {'latitude': 53.957805633545, 'longitude': -1.1303908824921},
#    'creation_timestamp': 1640596607},
#   {'name': 'York',
#    'coordinate': {'latitude': 53.959102630615, 'longitude': -1.1298018693924},
#    'creation_timestamp': 1640558167},
#   {'name': 'York',
#    'coordinate': {'latitude': 53.95911026001, 'longitude': -1.1297874450684},
#    'creation_timestamp': 1640558107},
#   {'name': 'Pocklington',
#    'coordinate': {'latitude': 53.924468994141, 'longitude': -0.77466952800751},
#    'creation_timestamp': 1640517307},
#   {'name': 'Heslington',
#    'coordinate': {'latitude': 53.928058624268, 'longitude': -1.0635010004044},
#    'creation_timestamp': 1640516140},
#   {'name': 'York',
#    'coordinate': {'latitude': 53.959102630615, 'longitude': -1.1297963857651},
#    'creation_timestamp': 1640470422},
#   {'name': 'Elvington',
#    'coordinate': {'latitude': 53.938446044922, 'longitude': -0.95182836055756},
#    'creation_timestamp': 1640468842},
#   {'name': 'Pocklington',
#    'coordinate': {'latitude': 53.924446105957, 'longitude': -0.77462446689606},
#    'creation_timestamp': 1640433691},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.839351654053, 'longitude': -1.5625687837601},
#    'creation_timestamp': 1640427861},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849559783936, 'longitude': -1.5644561052322},
#    'creation_timestamp': 1640361771},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.852245330811, 'longitude': -1.5735189914703},
#    'creation_timestamp': 1640359321},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.855121612549, 'longitude': -1.5734143257141},
#    'creation_timestamp': 1640358619},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.853202819824, 'longitude': -1.5672360658646},
#    'creation_timestamp': 1640358410},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849575042725, 'longitude': -1.5644056797028},
#    'creation_timestamp': 1640258974},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.850109100342, 'longitude': -1.5620554685593},
#    'creation_timestamp': 1640258369},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.853626251221, 'longitude': -1.5634109973907},
#    'creation_timestamp': 1640255656},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.

#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.854557037354, 'longitude': -1.5788820981979},
#    'creation_timestamp': 1633585069},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.852867126465, 'longitude': -1.5735356807709},
#    'creation_timestamp': 1633585009},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849559783936, 'longitude': -1.5644773244858},
#    'creation_timestamp': 1633554992},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.774116516113, 'longitude': -1.6047072410583},
#    'creation_timestamp': 1633554266},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.769386291504, 'longitude': -1.6211687326431},
#    'creation_timestamp': 1633544976},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.784996032715, 'longitude': -1.6040989160538},
#    'creation_timestamp': 1633544583},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849750518799, 'longitude': -1.5623704195023},
#    'creation_timestamp': 1633535959},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849540710449, 'longitude': -1.564440369606},
#    'creation_timestamp': 1633330851},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849555969238, 'longitude': -1.5644248723984},
#    'creation_timestamp': 1633268729},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.837146759033, 'longitude': -1.5869382619858},
#    'creation_timestamp': 1633268487},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849605560303, 'longitude': -1.5644077062607},
#    'creation_timestamp': 1633263724},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.858406066895, 'longitude': -1.567905664444},
#    'creation_timestamp': 1633263093},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849548339844, 'longitude': -1.5644390583038},
#    'creation_timestamp': 1633262479},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.861301422119, 'longitude': -1.5690387487411},
#    'creation_timestamp': 1633261143},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.780906677246, 'longitude': -1.5687209367752},
#    'creation_timestamp': 1633260886},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.778388977051, 'longitude': -1.5729044675827},
#    'creation_timestamp': 1633250951},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.797004699707, 'longitude': -1.6038236618042},
#    'creation_timestamp': 1633249420},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849552154541, 'longitude': -1.5644609928131},
#    'creation_timestamp': 1633204734},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.859649658203, 'longitude': -1.5719051361084},
#    'creation_timestamp': 1633204542},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849575042725, 'longitude': -1.5644474029541},
#    'creation_timestamp': 1633203810},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.859939575195, 'longitude': -1.5728974342346},
#    'creation_timestamp': 1633201395},
#   {'name': 'Gateshead',
#    'coordinate': {'latitude': 54.921890258789, 'longitude': -1.6223586797714},
#    'creation_timestamp': 1633200771},
#   {'name': 'Gateshead',
#    'coordinate': {'latitude': 54.958030700684, 'longitude': -1.6697778701782},
#    'creation_timestamp': 1633183840},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.882713317871, 'longitude': -1.5633516311646},
#    'creation_timestamp': 1633183072},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849555969238, 'longitude': -1.5644460916519},
#    'creation_timestamp': 1633109684},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849388122559, 'longitude': -1.5644313097},
#    'creation_timestamp': 1633107676},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849555969238, 'longitude': -1.5643929243088},
#    'creation_timestamp': 1632947429},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.811965942383, 'longitude': -1.5673952102661},
#    'creation_timestamp': 1632946346},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.77836227417, 'longitude': -1.5728693008423},
#    'creation_timestamp': 1632939651},
#   {'name': 'Durham',
#    'coordinate': {'latitude': 54.781761169434, 'longitude': -1.5754142999649},
#    'creation_timestamp': 1632939500},
#   {'name': 'Chester-le-Street',
#    'coordinate': {'latitude': 54.849559783936, 'longitude': -1.5644270181656},
#    'creation_timestamp': 1632764974}]}

# %%
for i in fb['location_history_v2']:
    lats.append(i['coordinate']['latitude'])
    longs.append(i['coordinate']['longitude'])
    stamps.append(int(str(i['creation_timestamp'])+'000'))

# %%
import geopy
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="your_app_name")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds = 1,   return_value_on_exception = None)

# %%
lats_clean=[]
for i in lats:
    if '.' not in str(i):
        lats_clean.append(float(str(i)[0:2]+'.'+str(i)[2:]))
    else:
        lats_clean.append(i)

# %%
longs_clean=[]
for i in longs:
    if '.' not in str(i):
        if '-' in str(i):
            if len(str(i))==8:
                longs_clean.append(float('-0.0'+str(i)[2:]))
            else:
                longs_clean.append(float(str(i)[0:2]+'.'+str(i)[2:]))
        else:
            
            longs_clean.append(float(str(i)[0:1]+'.'+str(i)[1:]))
    else:
        longs_clean.append(i)

# %%
longs
# Out:
# [-15644669,
#  -15624190,
#  -15607875,
#  -15628104,
#  -15647885,
#  -15645027,
#  -15638869,
#  -15726525,
#  -15730091,
#  -15725592,
#  -15644482,
#  -15645027,
#  -15644466,
#  -15722962,
#  -15730091,
#  -15723956,
#  -15644485,
#  -15645027,
#  -15642500,
#  -15624314,
#  -15607875,
#  -15624265,
#  -15646800,
#  -15645027,
#  -15644541,
#  -16210382,
#  -16209137,
#  -16202956,
#  -15645962,
#  -15645027,
#  -15644495,
#  -13708069,
#  -13706578,
#  -13707239,
#  -15461353,
#  -15465224,
#  -15448185,
#  -15644467,
#  -15645027,
#  -15644496,
#  -15691056,
#  -15692098,
#  -15689388,
#  -15645424,
#  -15645027,
#  -15644185,
#  -15717879,
#  -15729127,
#  -15724986,
#  -15759176,
#  -15758608,
#  -15757696,
#  -15728548,
#  -15729127,
#  -15727721,
#  -15644484,
#  -15645027,
#  -15643474,
#  -15713071,
#  -15730091,
#  -15725129,
#  -15647454,
#  -15645027,
#  -15643150,
#  -15726753,
#  -15730091,
#  -15714867,
#  -15644445,
#  -15645027,
#  -15644472,
#  -15627810,
#  -15607875,
#  -15645027,
#  -15644476,
#  -15728331,
#  -15730881,
#  -15728021,
#  -15644444,
#  -15645027,
#  -15643168,
#  -15756050,
#  -15762691,
#  -15766251,
#  -15636108,
#  -15645027,
#  -15645188,
#  -15634454,
#  -15645027,
#  -15644398,
#  -16209963,
#  -16209137,
#  -16203786,
#  -15646083,
#  -15645027,
#  -15639500,
#  -15711921,
#  -15711921,
#  -15725835,
#  -15730091,
#  -15729723,
#  -15644705,
#  -15645027,
#  -15644399,
#  -15646527,
#  -15645027,
#  -15644392,
#  -15755990,
#  -15763352,
#  -15749964,
#  -15644046,
#  -15645027,
#  -15644485,
#  -15773913,
#  -15777370,
#  -15774635,
#  -15691090,
#  -15688850,
#  -15690518,
#  -15644493,
#  -15644506,
#  -15647780,
#  -15680019,
#  -15680019,
#  -15723769,
#  -15730091,
#  -15727081,
#  -15541937,
#  -15547227,
#  -15544679,
#  -15403294,
#  -15402448,
#  -15411335,
#  -15396447,
#  -15412534,
#  -15409466,
#  -15644922,
#  -15644506,
#  -15644130,
#  -15921232,
#  -15919914,
#  -15920709,
#  -15646639,
#  -15644506,
#  -15642075,
#  -15623781,
#  -15607875,
#  -15624877,
#  -15641499,
#  -15644506,
#  -15644802,
#  -15721181,
#  -15730881,
#  -15725522,
#  -0.0199355,
#  -0.0201779,
#  -0.0233651,
#  -0.0245145,
#  -0.0243595,
#  3.300804,
#  3.300804,
#  2.751548,
#  2.735192,
#  2.735329,
#  2.188116,
#  2.1929,
#  2.205009,
#  -1.6665058,
#  -1.6676142,
#  -1.6660457,
#  -1.5635904,
#  -1.5645027,
#  -1.564443,
#  -1.5721452,
#  -1.5730718,
#  -1.5725112,
#  -1.5773457,
#  -1.5773571,
#  -1.5790764,
#  -1.5643819,
#  -1.5645027,
#  -1.5644439,
#  -1.5838173,
#  -1.5844866,
#  -1.5849331,
#  -1.5741644,
#  -1.5751917,
#  -1.5741539,
#  -1.5739628,
#  -1.5735323,
#  -1.5719953,
#  -1.5635383,
#  -1.5645027,
#  -1.5629207,
#  -1.5808349,
#  -1.5780799,
#  -1.5782163,
#  -1.6174773,
#  -1.6170742,
#  -1.6189652,
#  -2.828413,
#  -2.831209,
#  -2.8313664,
#  -3.9241936,
#  -3.9242919,
#  -3.9243819,
#  -4.591236,
#  -4.590511,
#  -4.5908571,
#  -4.7449585,
#  -4.7449081,
#  -4.7447526,
#  -4.7439786,
#  -4.7439712,
#  -4.7440878,
#  -4.7108772,
#  -4.710892,
#  -4.7108239,
#  -4.2491743,
#  -4.2471538,
#  -4.2501854,
#  -4.2528526,
#  -4.2536853,
#  -4.2532838,
#  -4.2568531,
#  -4.2581088,
#  -4.2584502,
#  -2.93321,
#  -2.9331356,
#  -2.9313686,
#  -1.6162592,
#  -1.6170742,
#  -1.6151609,
#  -1.5780522,
#  -1.5780522,
#  -1.5644808,
#  -1.5645027,
#  -1.5644436,
#  -1.5722441,
#  -1.5730718,
#  -1.5714729,
#  -1.5645038,
#  -1.5645027,
#  -1.5644387,
#  -1.5719659,
#  -1.5730718,
#  -1.5715775,
#  -1.5690367,
#  -1.5692098,
#  -1.5689679,
#  -1.5643528,
#  -1.5645027,
#  -1.5647422,
#  -1.5405665,
#  -1.5405665,
#  -1.5382788,
#  -1.5377549,
#  -1.5384669,
#  -1.5402635,
#  -1.5408296,
#  -1.5428076,
#  -1.5417779,
#  -1.5412812,
#  -1.5423618,
#  -1.563489,
#  -1.5645027,
#  -1.5641136,
#  -1.5883544,
#  -1.588585,
#  -1.5896461,
#  -1.5644052,
#  -1.5645027,
#  -1.5644184,
#  -1.5714016,
#  -1.5730091,
#  -1.5732313,
#  -1.5688177,
#  -1.5688177,
#  -1.5441881,
#  ...]

# %%
pd.DataFrame(longs)
# Out:
#              0
# 1541 -1.564393
# 1542 -1.567395
# 1543 -1.572869
# 1544 -1.575414
# 1545 -1.564427

# %%
import numpy as np

# %%
place=[]

for i in range(len(lats_clean)):
    location=geolocator.reverse((lats_clean[i], longs_clean[i]))
    try:
        place.append(location.raw['address']['village'])
    except:
        try:
            place.append(location.raw['address']['town'])
        except:
            try:
                place.append(location.raw['address']['city'])
            except:
                place.append(np.nan)

# %%
len(lats)
# Out:
# 1546

# %%
location.raw['address']['town']
# Out:
# 'Chester-le-Street'

# %%
place
# Out:
# ['Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Sunderland',
#  'Sunderland',
#  'Sunderland',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Birtley',
#  'Birtley',
#  'Birtley',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Gateshead',
#  'Gateshead',
#  'Gateshead',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'North Shields',
#  'North Shields',
#  'North Shields',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  nan,
#  nan,
#  nan,
#  'York',
#  'York',
#  'York',
#  nan,
#  nan,
#  nan,
#  'York',
#  'York',
#  'York',
#  'York',
#  'York',
#  'York',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  nan,
#  nan,
#  nan,
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'West Rainton',
#  'West Rainton',
#  'West Rainton',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Lanchester',
#  'Lanchester',
#  'Lanchester',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'High Shincliffe',
#  'High Shincliffe',
#  'High Shincliffe',
#  'High Shincliffe',
#  'High Shincliffe',
#  'High Shincliffe',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Pity Me',
#  'Pity Me',
#  'Pity Me',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Pity Me',
#  'Pity Me',
#  'Pity Me',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'City of Edinburgh',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'Berwick-upon-Tweed',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Lanchester',
#  'Lanchester',
#  'Lanchester',
#  'Pity Me',
#  'Pity Me',
#  'Pity Me',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'York',
#  'York',
#  'York',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'York',
#  'York',
#  'York',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Beamish',
#  'Beamish',
#  'Beamish',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'West Rainton',
#  'West Rainton',
#  'West Rainton',
#  'West Rainton',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Broompark',
#  'Broompark',
#  'Broompark',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Sherburn Hill',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Whickham',
#  'Whickham',
#  'Swalwell',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Whickham',
#  'Whickham',
#  'Whickham',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Middleton Tyas',
#  'Middleton Tyas',
#  'Middleton Tyas',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Pennard',
#  'Cardiff',
#  nan,
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  'London',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Middleton Tyas',
#  'Middleton Tyas',
#  'Middleton Tyas',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'South Pelaw',
#  'South Pelaw',
#  'South Pelaw',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Newcastle upon Tyne',
#  'Newcastle upon Tyne',
#  'Newcastle upon Tyne',
#  'Great Corby',
#  'Wetheral',
#  'Wetheral',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Castle Douglas',
#  'Monkton',
#  'Prestwick',
#  'Prestwick',
#  'Succoth',
#  'Succoth',
#  'Succoth',
#  'Arrochar',
#  'Succoth',
#  'Succoth',
#  'Tarbet',
#  'Tarbet',
#  'Tarbet',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Glasgow',
#  'Carlisle',
#  'Carlisle',
#  'Carlisle',
#  'Newcastle upon Tyne',
#  'Newcastle upon Tyne',
#  'Newcastle upon Tyne',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Harrogate',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Chester-le-Street',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'Durham',
#  'High Shincliffe',
#  ...]

# %%
pl=pd.DataFrame({'Place':place})

# %%
n=
geolocator.reverse((lats_clean[n], longs_clean[n]))
# Out:
# Location(England, United Kingdom, (52.5310214, -1.2649062, 0.0))

# %%
pla=[]
lati=[]
latic=[]
longi=[]
longic=[]
ts=[]

for i in pl[pl.Place.isnull()].index:
    #pla.append(geolocator.reverse((lats_clean[i], longs_clean[i])))
    #lati.append(lats[i])
    #latic.append(lats_clean[i])
    #longi.append(longs[i])
    #longic.append(longs_clean[i])
    ts.append(stamps[i])

# %%
fg=pd.DataFrame({'Place':pla,'Lat Unclean':lati,'Lat Clean':latic,'Long Unclean':longi,'Long Clean':longic,'TS':ts})

# %%
datetime.datetime.fromtimestamp(int(stamps[0])//1000.0)
# Out:
# datetime.datetime(2021, 12, 1, 7, 46, 37)

# %%
fg['TS']=fg.TS.apply(lambda x: datetime.datetime.fromtimestamp(int(x)//1000.0))

# %%
df4=pd.DataFrame({'Place':place,'TS':stamps})
df4['TS']=df4.TS.apply(lambda x: datetime.datetime.fromtimestamp(int(x)//1000.0))

# %%
df4
# Out:
#                   Place                  TS
# 0     Chester-le-Street 2021-12-01 07:46:37
# 1     Chester-le-Street 2021-12-01 07:50:39
# 2     Chester-le-Street 2021-12-01 07:50:39
# 3     Chester-le-Street 2021-12-01 08:44:53
# 4     Chester-le-Street 2021-12-01 08:47:03
# ...                 ...                 ...
# 1541  Chester-le-Street 2021-09-29 21:30:29
# 1542            Pity Me 2021-09-29 21:12:26
# 1543             Durham 2021-09-29 19:20:51
# 1544             Durham 2021-09-29 19:18:20
# 1545  Chester-le-Street 2021-09-27 18:49:34
#
# [1546 rows x 2 columns]

# %%
df4a=df4[df4.Place.isnull()==False]

# %%
df4b=df4[df4.Place.isnull()==True]

# %%
df4b.reset_index(drop=True,inplace=True)

# %%
df4b['Place']=pls
# Out:
# C:\Users\Alastair Tyson\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df4=pd.concat([df4a,df4b])

# %%
pls=[]

for i in fg.Place:
    print(i)
    inputs=input('? ')
    pls.append(inputs)
# Out:
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# A75, Cargenbridge, Dumfries and Galloway, Scotland, DG2 8PT, United Kingdom
# ? Dumfries
# A75, Cargenbridge, Dumfries and Galloway, Scotland, DG2 8PT, United Kingdom
# ? Dumfries
# A75, Cargenbridge, Dumfries and Galloway, Scotland, DG2 8PT, United Kingdom
# ? Dumfries
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# England, United Kingdom
# ? Pocklington
# R579, Allow ED, The Municipal District of Kanturk – Mallow, County Cork, Munster, Éire / Ireland
# ? Cambridge
# Imphrick, The Municipal District of Kanturk – Mallow, County Cork, Munster, P51 NW93, Éire / Ireland
# ? Cambridge
# Templemolaga, The Municipal District of Fermoy, County Cork, Munster, P67AV27, Éire / Ireland
# ? Cambridger
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# Nederland
# ? Shenfield
# Nederland
# ? Shenfield
# Nederland
# ? Shenfield
# Llwybr Arfordirol Cymru, Margam Moors, Neath Port Talbot, Cymru / Wales, SA13 2PH, United Kingdom
# ? City of Westminster
# Nederland
# ? Shenfield
# Nederland
# ? Shenfield
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# None
# ? Pilgrims Hatch
# Dumfries and Galloway, Scotland, DG12 6RR, United Kingdom
# ? Dumfries
# Dumfries and Galloway, Scotland, United Kingdom
# ? Dumfries
# Fox Barn, Stockton Road, South Kilvington, Hambleton, North Yorkshire, Yorkshire and the Humber, England, YO7 2NA, United Kingdom
# ? Thirsk
# A1(M), North Lodge, County Durham, North East England, England, DH3 2HR, United Kingdom
# ? Chester-le-Street
# 40, Holborn Viaduct, Smithfield, City of London, Greater London, England, EC1N 2PZ, United Kingdom
# ? City of Westminster
# Ash Meadows, North Lodge, County Durham, North East England, England, NE38 9HN, United Kingdom
# ? Chester-le-Street

# %%
df4.reset_index(drop=True,inplace=True)

# %%
df4
# Out:
#                     Place                  TS
# 0       Chester-le-Street 2021-12-01 07:46:37
# 1       Chester-le-Street 2021-12-01 07:50:39
# 2       Chester-le-Street 2021-12-01 07:50:39
# 3       Chester-le-Street 2021-12-01 08:44:53
# 4       Chester-le-Street 2021-12-01 08:47:03
# ...                   ...                 ...
# 1541             Dumfries 2021-12-30 14:12:27
# 1542               Thirsk 2021-12-27 16:23:17
# 1543    Chester-le-Street 2021-11-09 18:16:58
# 1544  City of Westminster 2021-10-30 20:00:12
# 1545    Chester-le-Street 2021-10-27 18:40:52
#
# [1546 rows x 2 columns]

# %%
df4['Place']=why

# %%
dic['Shenfield']=[51.62944508341057, 0.319231909556979]

# %%
latt=[]
longg=[]


for i in range(len(df4)):
    try:
        latt.append(dic[df4.iloc[i,0]][0])
        longg.append(dic[df4.iloc[i,0]][1])
    except:
        print(df4.iloc[i,0])

# %%
why=[]

for i in plsa:
    if i =='London':
        why.append('City of Westminster')
    elif i=='Cambridger':
        why.append('Cambridge')
    elif i=='City of Edinburgh':
        why.append('Edinburgh')
    elif i=='Pilgrims Hatch':
        why.append("Pilgrims' Hatch")
    elif i=='Pennard' or i== 'Cardiff':
        why.append('City of Westminster')
    elif i=='South Pelaw':
        why.append('Chester-le-Street')
    elif i=='Allerthorpe':
        why.append('Pocklington')
    else:
        why.append(i)

# %%
dic={}
for i in range(len(df)):
    lat=df.iloc[i,0]
    long=df.iloc[i,1]
    plac=df.iloc[i,3]
    dic[plac]=[lat,long]

# %%
len(latt)
# Out:
# 0

# %%
df4['Longitude']=longg

# %%
df4.Place.unique()
# Out:
# array(['Chester-le-Street', 'Durham', 'Broompark', 'Sunderland',
#        'Washington', 'Birtley', 'Gateshead', 'Sherburn Hill',
#        'North Shields', 'York', 'City of Edinburgh', 'Castle Douglas',
#        'Berwick-upon-Tweed', 'West Rainton', 'Lanchester',
#        'High Shincliffe', 'Pity Me', 'Whickham', 'London', 'Beamish',
#        'Swalwell', 'Middleton Tyas', 'Pennard', 'Cardiff', 'South Pelaw',
#        'Newcastle upon Tyne', 'Great Corby', 'Wetheral', 'Monkton',
#        'Prestwick', 'Succoth', 'Arrochar', 'Tarbet', 'Glasgow',
#        'Carlisle', 'Harrogate', 'Brunswick Village', 'Pocklington',
#        'Allerthorpe', 'Elvington', 'Great Lumley', 'Jarrow',
#        'High Pittington', 'Woodstone Village', 'Lamesley', 'Kimblesworth',
#        'Framwellgate Moor', 'Edmondsley', 'Bearpark', 'Kibblesworth',
#        'Haddington', 'Town Yetholm', 'Chester Moor', 'Sacriston',
#        'Longhorsley', 'Reston', 'Innerwick', 'Glororum', 'Chilton',
#        'Corby Glen', 'Navestock', 'South Weald', "Pilgrims' Hatch",
#        'City of Westminster', 'Brentwood', 'Maggots End',
#        'South Cambridgeshire', 'Austerfield', 'Hett', 'Urpeth',
#        'Sherburn', 'Easingwold', 'Hayton', 'Middleton St George',
#        'High Handenhold', 'Laneham', 'Stretton', 'Low Dinsdale',
#        'Dumfries', 'Cambridge', 'Cambridger', 'Pilgrims Hatch',
#        'Shenfield', 'Thirsk'], dtype=object)

# %%
df.Place.unique()
# Out:
# array(['Warley', "Pilgrims' Hatch", 'Billericay', 'Little Burstead',
#        'Castle Douglas', 'Stranraer', 'Harpenden', 'City of Westminster',
#        'Stanford Rivers', 'Stratford', 'Chelmsford', 'Sonning Common',
#        'Carlisle', 'Edinburgh', 'Romford', 'Basildon', 'South Weald',
#        'Brentwood', 'Durweston', 'Oxshott', 'Hatfield', 'Stevenage',
#        'Hutton', 'Cambridge', 'Harold Wood', 'Bracknell', 'Greenhithe',
#        'Southend-on-Sea', 'Rome', 'Florence', 'Venice', 'Colchester',
#        'Epping', 'Ilford', 'Loughton', 'Yalding', 'Barnstaple', 'Penrith',
#        'Chappel', 'Ingatestone', 'Ingrave', 'Leatherhead', 'Dartford',
#        'Ashford', 'Hythe', 'Coquelles', 'Recques-sur-Hem', 'Holque',
#        'Zuytpeene', 'Hazebrouck', 'Méteren', 'Capinghem', 'Verlinghem',
#        'Lambersart', 'Lille', 'Vendeville', 'Camphin-en-Carembault',
#        'Oignies', 'Dourges', 'Izel-lès-Équerchin', 'Fampoux', 'Bapaume',
#        'Herbécourt', 'Roye', 'Arsy', 'Chevrières', 'Othis',
#        'Roissy-En-France', 'Sarcelles', 'Pierrefitte-sur-Seine',
#        'Coupvray', 'Chessy', 'Paris', 'Zouafques', 'Calais', 'Folkestone',
#        'Lenham', 'Hollingbourne', 'Camden Town', 'Saint Albans',
#        'Herongate', 'South Ockendon', 'Upminster', 'Wimbledon', 'Esher',
#        'Chigwell', 'Thundersley', 'Chipping Ongar', 'Wheathampstead',
#        'Worcester Park Estate', 'Grays', 'Takeley Street', 'Needham',
#        'Diss', 'Welwyn', 'Stansted', 'Glasgow', 'Killin', 'St Andrews',
#        'Liverpool Street', 'Hastingwood', 'Mountnessing',
#        'South Willesborough', 'Bristol', 'Stapleford Tawney',
#        'Waltham Abbey', 'Kensington', 'Ilfracombe', 'Stags Head',
#        'East Buckland', 'Havering atte Bower', 'Islington',
#        "Bishop's Stortford", 'Bishops Stortford', 'Birchanger',
#        'Doddinghurst', 'Millbrook', 'Lidlington', 'Wickford',
#        'Regents Wharf', 'Downside', 'Aldershot', 'Bicester',
#        'Great Burstead', 'Ryedale', 'Low Catton', 'York', 'Worksop',
#        'Brighton and Hove', 'Bulphan', 'Witham', 'Maldon', 'Tiptree',
#        'Molehill Green', 'Paisley', 'Kilmarnock', 'Ayr', 'Prestwick',
#        'Renfrew', 'Barking', 'Cobham', 'Elmbridge', 'Staines', 'Longford',
#        'New York', 'East Rutherford', 'Secaucus', 'Bayonne', 'Hounslow',
#        'Hornchurch', 'Welwyn Garden City', 'Greenwich', 'Potters Bar',
#        'Watford', 'Warner Bros. Studio Tour London', 'Abbots Langley',
#        'Hemel Hempstead', 'Corner Hall', 'City of London', 'Aldgate',
#        'Iver', 'Swindon', 'Westward Ho!', 'Portbury', 'Waterloo',
#        'Exminster', 'Ebford', 'Exeter', 'Ealing', 'West Suffolk',
#        'Ridgmont', 'Harlow', 'Finchley', 'Willesden', 'Isleworth',
#        'Chiswick', 'Woburn', 'Long Buckby', 'Corley', 'Ash Green',
#        'Stafford', 'Stoke-on-Trent', 'Hanley', 'Audley', 'Sandbach',
#        'Knutsford', 'Greenholme', 'Thornhill', 'Biggar',
#        'Gatehouse of Fleet', 'Haugh of Urr', 'Dumfries', 'Middlewich',
#        'Cannock', 'Norton Canes', 'Gidea Park', 'Coxtie Green',
#        'White Roothing', 'Birch', 'Huntingdon', 'Cockermouth',
#        'Harrogate', 'Darlington', "Cream o' Galloway", 'Kirkcudbright',
#        'Cairnsmore of Fleet', 'Otter Pool', 'Annan', 'Bolton', 'Alsager',
#        'Crewe', 'Madeley Heath', 'Madeley', 'Keele', 'Bedford',
#        'Purfleet', 'Havering', 'Highwood', 'Royston', 'Castor', 'Haddon',
#        'East Retford', 'Northallerton', 'Crook', 'Durham',
#        'Sherburn Hill', 'Spennymoor', 'Shincliffe', 'Chester-le-Street',
#        'Bishop Auckland', 'High Force', 'South Milford', 'Newark',
#        'Parkhill', 'Bedale', 'Cowthorpe', 'Feering', 'Hatfield Peverel',
#        'Manor Park', 'Forest Gate', 'Lutton', 'Harworth', 'Moor Monkton',
#        'Green Hammerton', 'Upper Poppleton', 'Sedgefield', 'Birtley',
#        'Gateshead', 'Swalwell', 'Newcastle upon Tyne', 'Whickham',
#        'Washington', 'Skellingthorpe', 'Houghton le Spring', 'Goole',
#        'Grantham', 'Thirsk', 'Barnard Castle', 'Keswick', 'Wreay',
#        'Brampton', 'St Helen Auckland', 'Appleby', 'Allerdale',
#        'Stainton', 'Prudhoe', 'Hexham', 'Haltwhistle', 'Eden',
#        'Great Ouseburn', 'Boxworth', 'Great Staughton', 'Kelvedon Hatch',
#        'Bowers Gifford', 'Saffron Walden', 'Newton Stewart', 'Donaghadee',
#        'Cairnryan', 'Belfast', 'Ballyclare', 'Newtownabbey', 'Ballymena',
#        'Broughshane', 'Cumnock', 'Alexandria', 'Balloch', 'Tarbet',
#        'Crianlarich', 'Tyndrum', 'Fort William', 'Glenfinnan',
#        'Glen Nevis', 'Fort Augustus', 'Inverness', 'Urquhart Castle',
#        'Drumnadrochit', 'Aviemore', 'Newtonmore', 'Pitlochry',
#        'Killiecrankie', 'Aberfeldy', 'Callander', 'Stirling',
#        'Bridge of Allan', "Bo'ness", 'Pathhead', 'Seaton Burn',
#        'Cramlington', 'Framwellgate Moor', 'Pity Me', 'Pocklington',
#        'Elvington', 'Wetheral', 'Monkton', 'Arrochar', 'Succoth',
#        'Clydebank', 'Lockerbie', 'Broompark'], dtype=object)

# %%
df4=df4[['Latitude','Longitude','TS','Place']]

# %%
df4.columns=['Latitude','Longitude','Date','Place']

# %%
df4
# Out:
#       Latitude  Longitude                Date                Place
# 0     54.85432   -1.57504 2021-12-01 07:46:37    Chester-le-Street
# 1     54.85432   -1.57504 2021-12-01 07:50:39    Chester-le-Street
# 2     54.85432   -1.57504 2021-12-01 07:50:39    Chester-le-Street
# 3     54.85432   -1.57504 2021-12-01 08:44:53    Chester-le-Street
# 4     54.85432   -1.57504 2021-12-01 08:47:03    Chester-le-Street
# ...        ...        ...                 ...                  ...
# 1541  55.06984   -3.60923 2021-12-30 14:12:27             Dumfries
# 1542  54.23277   -1.34238 2021-12-27 16:23:17               Thirsk
# 1543  54.85432   -1.57504 2021-11-09 18:16:58    Chester-le-Street
# 1544  51.49732   -0.13715 2021-10-30 20:00:12  City of Westminster
# 1545  54.85432   -1.57504 2021-10-27 18:40:52    Chester-le-Street
#
# [1546 rows x 4 columns]

# %%
df5
# Out:
#       Latitude  Longitude                Date                Place
# 0     51.60840    0.29726 2014-08-11 04:36:00               Warley
# 1     51.60840    0.29726 2014-09-11 12:59:00               Warley
# 2     51.60840    0.29726 2014-10-11 16:02:00               Warley
# 3     51.60840    0.29726 2014-10-11 16:18:00               Warley
# 4     51.60840    0.29726 2014-10-11 22:15:00               Warley
# ...        ...        ...                 ...                  ...
# 1541  55.06984   -3.60923 2021-12-30 14:12:27             Dumfries
# 1542  54.23277   -1.34238 2021-12-27 16:23:17               Thirsk
# 1543  54.85432   -1.57504 2021-11-09 18:16:58    Chester-le-Street
# 1544  51.49732   -0.13715 2021-10-30 20:00:12  City of Westminster
# 1545  54.85432   -1.57504 2021-10-27 18:40:52    Chester-le-Street
#
# [18134 rows x 4 columns]

# %%
df5=pd.concat([df3,df4])

# %%
df6=df5[df5.Date<datetime.datetime(2022,1,1)].sort_values(by='Date').drop_duplicates().reset_index(drop=True)

# %%
df6.to_csv('tracking_activity_v3.csv',index=False,encoding='utf-8-sig')
